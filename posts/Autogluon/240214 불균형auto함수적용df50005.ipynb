# %% [raw]
# ---
# title: "[Autogluon] df50_tr, df005_tst"
# author: "김보람"
# date: "02/14/2024"
# ---

# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions-auto.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %%
auto_amt_nb2(fraudTrain,10)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.879535  0.047633  0.892045  0.090438
# 1        KNeighborsDist  None  0.874805  0.045641  0.886364  0.086811
# 2            LightGBMXT  None  0.886477  0.050706  0.897727  0.095990
# 3              LightGBM  None  0.911120  0.064320  0.903409  0.120091
# 4      RandomForestGini  None  0.856189  0.041113  0.914773  0.078690
# 5      RandomForestEntr  None  0.856189  0.041113  0.914773  0.078690
# 6              CatBoost  None  0.902575  0.059303  0.909091  0.111343
# 7        ExtraTreesGini  None  0.863246  0.042662  0.903409  0.081476
# 8        ExtraTreesEntr  None  0.866336  0.043609  0.903409  0.083203
# 9       NeuralNetFastAI  None  0.967080  0.137276  0.738636  0.231523
# 10              XGBoost  None  0.909517  0.063246  0.903409  0.118216
# 11       NeuralNetTorch  None  0.883082  0.050140  0.914773  0.095069
# ...

# %%
auto_amt_nb3(fraudTrain,10)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.874100  0.009706  0.864865  0.019196
# 1        KNeighborsDist  None  0.871251  0.008910  0.810811  0.017626
# 2            LightGBMXT  None  0.942902  0.017356  0.702703  0.033876
# 3              LightGBM  None  0.918146  0.013960  0.810811  0.027447
# 4      RandomForestGini  None  0.853964  0.007862  0.810811  0.015572
# 5      RandomForestEntr  None  0.853964  0.007862  0.810811  0.015572
# 6              CatBoost  None  0.915682  0.013556  0.810811  0.026667
# 7        ExtraTreesGini  None  0.861125  0.008264  0.810811  0.016362
# 8        ExtraTreesEntr  None  0.860355  0.008488  0.837838  0.016807
# 9       NeuralNetFastAI  None  0.973395  0.035511  0.675676  0.067476
# 10              XGBoost  None  0.911138  0.012870  0.810811  0.025338
# 11       NeuralNetTorch  None  0.943749  0.018268  0.729730  0.035644
# ...
