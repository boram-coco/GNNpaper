# %% [raw]
# ---
# title: "[Autogluon] df0.04_tr, df0.04_tst"
# author: "김보람"
# date: "02/20/2024"
# ---

# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions-auto.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %%
auto_amt_nb4(fraudTrain,0.04)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.976397  0.758361  0.603059  0.671852
# 1        KNeighborsDist  None  0.974559  0.738075  0.565824  0.640572
# 2            LightGBMXT  None  0.959934  0.000000  0.000000  0.000000
# 3              LightGBM  None  0.975785  0.802030  0.525266  0.634793
# 4      RandomForestGini  None  0.972321  0.704485  0.532580  0.606588
# 5      RandomForestEntr  None  0.972321  0.704485  0.532580  0.606588
# 6              CatBoost  None  0.975598  0.749153  0.587766  0.658718
# 7        ExtraTreesGini  None  0.974133  0.731941  0.559176  0.633999
# 8        ExtraTreesEntr  None  0.974053  0.731239  0.557181  0.632453
# 9       NeuralNetFastAI  None  0.974080  0.854473  0.425532  0.568131
# 10              XGBoost  None  0.976371  0.736398  0.638963  0.684229
# 11       NeuralNetTorch  None  0.977143  0.776541  0.603059  0.678892
# ...
