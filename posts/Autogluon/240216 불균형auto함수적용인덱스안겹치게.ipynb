# %% [raw]
# ---
# title: "[Autogluon] df50_tr, df00_tst(인덱스안겹치게)"
# author: "김보람"
# date: "02/16/2024"
# ---

# %% [markdown]
# # imports

# %% [markdown]
# 1. 2/16
#
# 2. 4/5

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions-auto.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %%
auto_amt_nb3(fraudTrain,10)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.878412  0.008791  0.965517  0.017424
# 1        KNeighborsDist  None  0.870904  0.007117  0.827586  0.014113
# 2            LightGBMXT  None  0.884110  0.007923  0.827586  0.015697
# 3              LightGBM  None  0.901013  0.009645  0.862069  0.019077
# 4      RandomForestGini  None  0.853579  0.006279  0.827586  0.012464
# 5      RandomForestEntr  None  0.853579  0.006279  0.827586  0.012464
# 6              CatBoost  None  0.908251  0.010399  0.862069  0.020551
# 7        ExtraTreesGini  None  0.859970  0.006834  0.862069  0.013561
# 8        ExtraTreesEntr  None  0.861433  0.006906  0.862069  0.013702
# 9       NeuralNetFastAI  None  0.959111  0.019535  0.724138  0.038043
# 10              XGBoost  None  0.905132  0.010060  0.862069  0.019889
# 11       NeuralNetTorch  None  0.904978  0.009650  0.827586  0.019078
# ...

# %%
auto_amt_nb3(fraudTrain,9)
# Out:
#                   model  time       acc       pre   rec        f1       auc  \
# 0        KNeighborsUnif  None  0.874177  0.011187  0.82  0.022073  0.915025
# 1        KNeighborsDist  None  0.867597  0.010889  0.84  0.021500  0.879684
# 2            LightGBMXT  None  0.887719  0.013118  0.86  0.025841  0.939287
# 3              LightGBM  None  0.900256  0.014080  0.82  0.027684  0.950563
# 4      RandomForestGini  None  0.850177  0.009858  0.86  0.019492  0.922707
# 5      RandomForestEntr  None  0.850177  0.009858  0.86  0.019492  0.922707
# 6              CatBoost  None  0.894542  0.013641  0.84  0.026846  0.944163
# 7        ExtraTreesGini  None  0.858939  0.010226  0.84  0.020207  0.926876
# 8        ExtraTreesEntr  None  0.857415  0.010354  0.86  0.020462  0.927769
# 9       NeuralNetFastAI  None  0.966059  0.038690  0.78  0.073724  0.881693
# 10              XGBoost  None  0.898282  0.013809  0.82  0.027161  0.948738
# ...

# %%
auto_amt_nb3(fraudTrain,8)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.877723  0.011463  0.867925  0.022627
# 1        KNeighborsDist  None  0.872523  0.011233  0.886792  0.022186
# 2            LightGBMXT  None  0.886615  0.011828  0.830189  0.023324
# 3              LightGBM  None  0.901815  0.013941  0.849057  0.027431
# 4      RandomForestGini  None  0.852031  0.009691  0.886792  0.019172
# 5      RandomForestEntr  None  0.852031  0.009691  0.886792  0.019172
# 6              CatBoost  None  0.895200  0.013070  0.849057  0.025744
# 7        ExtraTreesGini  None  0.861200  0.010325  0.886792  0.020413
# 8        ExtraTreesEntr  None  0.859754  0.010433  0.905660  0.020627
# 9       NeuralNetFastAI  None  0.965723  0.035871  0.773585  0.068562
# 10              XGBoost  None  0.900123  0.013707  0.849057  0.026978
# 11       NeuralNetTorch  None  0.886923  0.012123  0.849057  0.023904
# ...

# %%
auto_amt_nb3(fraudTrain,7)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.876482  0.010799  0.909091  0.021345
# 1        KNeighborsDist  None  0.870878  0.010537  0.927273  0.020838
# 2            LightGBMXT  None  0.887204  0.011584  0.890909  0.022870
# 3              LightGBM  None  0.901239  0.013473  0.909091  0.026553
# 4      RandomForestGini  None  0.852478  0.008522  0.854545  0.016876
# 5      RandomForestEntr  None  0.852478  0.008522  0.854545  0.016876
# 6              CatBoost  None  0.895339  0.012475  0.890909  0.024605
# 7        ExtraTreesGini  None  0.861099  0.009802  0.927273  0.019399
# 8        ExtraTreesEntr  None  0.859914  0.009720  0.927273  0.019238
# 9       NeuralNetFastAI  None  0.964952  0.034380  0.836364  0.066045
# 10              XGBoost  None  0.899569  0.013252  0.909091  0.026123
# 11       NeuralNetTorch  None  0.887608  0.011625  0.890909  0.022951
# ...

# %%
auto_amt_nb3(fraudTrain,6)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.874137  0.008019  0.830189  0.015884
# 1        KNeighborsDist  None  0.869382  0.007729  0.830189  0.015315
# 2            LightGBMXT  None  0.883256  0.009412  0.905660  0.018630
# 3              LightGBM  None  0.898631  0.010163  0.849057  0.020085
# 4      RandomForestGini  None  0.850821  0.006924  0.849057  0.013736
# 5      RandomForestEntr  None  0.850821  0.006924  0.849057  0.013736
# 6              CatBoost  None  0.890897  0.009654  0.867925  0.019095
# 7        ExtraTreesGini  None  0.860124  0.007382  0.849057  0.014637
# 8        ExtraTreesEntr  None  0.858577  0.007461  0.867925  0.014796
# 9       NeuralNetFastAI  None  0.964933  0.025873  0.754717  0.050031
# 10              XGBoost  None  0.896461  0.009951  0.849057  0.019672
# 11       NeuralNetTorch  None  0.883371  0.009421  0.905660  0.018648
# ...

# %%
auto_amt_nb3(fraudTrain,5)
# Out:
#                   model  time       acc       pre       rec        f1  \
# 0        KNeighborsUnif  None  0.875715  0.007542  0.844828  0.014950
# 1        KNeighborsDist  None  0.870383  0.006651  0.775862  0.013189
# 2            LightGBMXT  None  0.886128  0.008392  0.862069  0.016622
# 3              LightGBM  None  0.900814  0.009625  0.862069  0.019037
# 4      RandomForestGini  None  0.851481  0.005808  0.775862  0.011530
# 5      RandomForestEntr  None  0.851481  0.005808  0.775862  0.011530
# 6              CatBoost  None  0.894000  0.009011  0.862069  0.017835
# 7        ExtraTreesGini  None  0.860874  0.006198  0.775862  0.012298
# 8        ExtraTreesEntr  None  0.858911  0.006247  0.793103  0.012396
# 9       NeuralNetFastAI  None  0.964391  0.023404  0.758621  0.045408
# 10              XGBoost  None  0.898273  0.009386  0.862069  0.018570
# 11       NeuralNetTorch  None  0.885897  0.008375  0.862069  0.016589
# ...

# %%
auto_amt_nb3(fraudTrain,4)

# %%
auto_amt_nb3(fraudTrain,3)

# %%
auto_amt_nb3(fraudTrain,2)

# %%
auto_amt_nb3(fraudTrain,1)
