# %% [raw]
# ---
# title: "[GNN] 신용카드거래 사기탐지 – pyod 사용"
# author: "신록예찬,김보람 "
# date: "02/01/2024"
# ---

# %% [markdown]
# ref: <https://pyod.readthedocs.io/en/latest/pyod.models.html#all-models>
#
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime
# Out:
# /tmp/ipykernel_3490192/761229760.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run functions.py

# %%
with open('fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %% [markdown]
# > pyod에 random_state 매개변수가 명시되어 있지 않다..? 클래스 작성해야 하는뎀..

# %% [markdown]
# # 2.

# %% [markdown]
# ## 시도1(0.3 / 0.05)

# %%
pyod(*pyod_preprocess(fraudTrain, 0.3, 0.05))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ABOD  0.752989  0.950050  0.000000  0.000000  0.000000  0.500000
# 1     COPOD  0.004074  0.749417  0.138138  0.766667  0.234097  0.757589
# 2      ECOD  0.003891  0.719447  0.116768  0.703333  0.200285  0.711814
# 3       GMM  0.080132  0.706294  0.093785  0.563333  0.160799  0.638572
# 4      HBOS  0.002255  0.949717  0.000000  0.000000  0.000000  0.499825
# 5   IForest  0.196480  0.822844  0.187398  0.763333  0.300920  0.794653
# 6      INNE  0.428953  0.739594  0.116505  0.640000  0.197125  0.692415
# 7       KDE  4.580457  0.845155  0.213115  0.780000  0.334764  0.814290
# 8       KNN  0.015898  0.816683  0.176755  0.730000  0.284600  0.775620
# 9      LODA  0.060742  0.949717  0.000000  0.000000  0.000000  0.499825
# 10      LOF  0.037978  0.511988  0.051483  0.503333  0.093412  0.507888
# 11      MAD  0.001551  0.961205  0.646288  0.493333  0.559546  0.739569
# 12      MCD  0.005365  0.847486  0.215867  0.780000  0.338150  0.815517
# 13    OCSVM  8.742899  0.808525  0.171561  0.740000  0.278545  0.776064
# 14      PCA  0.002501  0.454545  0.020619  0.213333  0.037603  0.340280
# 15      ROD  1.897241  0.583417  0.027062  0.210000  0.047945  0.406525
#
#     graph_based  pyod  throw_rate  train_size train_cols  train_frate  \
# 0         False  True         0.3       14014      [amt]     0.407164
# 1         False  True         0.3       14014      [amt]     0.407164
# 2         False  True         0.3       14014      [amt]     0.407164
# 3         False  True         0.3       14014      [amt]     0.407164
# 4         False  True         0.3       14014      [amt]     0.407164
# 5         False  True         0.3       14014      [amt]     0.407164
# 6         False  True         0.3       14014      [amt]     0.407164
# 7         False  True         0.3       14014      [amt]     0.407164
# 8         False  True         0.3       14014      [amt]     0.407164
# 9         False  True         0.3       14014      [amt]     0.407164
# 10        False  True         0.3       14014      [amt]     0.407164
# 11        False  True         0.3       14014      [amt]     0.407164
# 12        False  True         0.3       14014      [amt]     0.407164
# 13        False  True         0.3       14014      [amt]     0.407164
# 14        False  True         0.3       14014      [amt]     0.407164
# 15        False  True         0.3       14014      [amt]     0.407164
#
#     test_size  test_frate hyper_params
# 0        6006     0.04995         None
# 1        6006     0.04995         None
# 2        6006     0.04995         None
# 3        6006     0.04995         None
# 4        6006     0.04995         None
# 5        6006     0.04995         None
# 6        6006     0.04995         None
# 7        6006     0.04995         None
# 8        6006     0.04995         None
# 9        6006     0.04995         None
# 10       6006     0.04995         None
# 11       6006     0.04995         None
# 12       6006     0.04995         None
# 13       6006     0.04995         None
# 14       6006     0.04995         None
# 15       6006     0.04995         None

# %% [markdown]
# ## 시도2(0.3 / 0.005)

# %%
pyod(*pyod_preprocess(fraudTrain, 0.3, 0.005))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ABOD  0.769208  0.995005  0.000000  0.000000  0.000000  0.500000
# 1     COPOD  0.004077  0.722611  0.015976  0.900000  0.031395  0.810860
# 2      ECOD  0.003934  0.712121  0.013738  0.800000  0.027012  0.755840
# 3       GMM  0.068339  0.703130  0.010609  0.633333  0.020868  0.668407
# 4      HBOS  0.002113  0.994672  0.000000  0.000000  0.000000  0.499833
# 5   IForest  0.185365  0.819847  0.024412  0.900000  0.047535  0.859722
# 6      INNE  0.427760  0.725275  0.011460  0.633333  0.022512  0.679535
# 7       KDE  4.592304  0.835498  0.026680  0.900000  0.051823  0.867587
# 8       KNN  0.015570  0.805361  0.020219  0.800000  0.039441  0.802694
# 9      LODA  0.054602  0.994672  0.000000  0.000000  0.000000  0.499833
# 10      LOF  0.037884  0.494339  0.003632  0.366667  0.007192  0.430823
# 11      MAD  0.001662  0.984682  0.177083  0.566667  0.269841  0.776724
# 12      MCD  0.005319  0.835997  0.026759  0.900000  0.051973  0.867838
# 13    OCSVM  8.734179  0.776557  0.019062  0.866667  0.037303  0.821386
# 14      PCA  0.002419  0.419414  0.000866  0.100000  0.001718  0.260509
# 15      ROD  2.139708  0.561605  0.001150  0.100000  0.002274  0.331961
#
#     graph_based  pyod  throw_rate  train_size train_cols  train_frate  \
# 0         False  True         0.3       14014      [amt]     0.426431
# 1         False  True         0.3       14014      [amt]     0.426431
# 2         False  True         0.3       14014      [amt]     0.426431
# 3         False  True         0.3       14014      [amt]     0.426431
# 4         False  True         0.3       14014      [amt]     0.426431
# 5         False  True         0.3       14014      [amt]     0.426431
# 6         False  True         0.3       14014      [amt]     0.426431
# 7         False  True         0.3       14014      [amt]     0.426431
# 8         False  True         0.3       14014      [amt]     0.426431
# 9         False  True         0.3       14014      [amt]     0.426431
# 10        False  True         0.3       14014      [amt]     0.426431
# 11        False  True         0.3       14014      [amt]     0.426431
# 12        False  True         0.3       14014      [amt]     0.426431
# 13        False  True         0.3       14014      [amt]     0.426431
# 14        False  True         0.3       14014      [amt]     0.426431
# 15        False  True         0.3       14014      [amt]     0.426431
#
#     test_size  test_frate hyper_params
# 0        6006    0.004995         None
# 1        6006    0.004995         None
# 2        6006    0.004995         None
# 3        6006    0.004995         None
# 4        6006    0.004995         None
# 5        6006    0.004995         None
# 6        6006    0.004995         None
# 7        6006    0.004995         None
# 8        6006    0.004995         None
# 9        6006    0.004995         None
# 10       6006    0.004995         None
# 11       6006    0.004995         None
# 12       6006    0.004995         None
# 13       6006    0.004995         None
# 14       6006    0.004995         None
# 15       6006    0.004995         None

# %% [markdown]
# ## 시도3(0.2 / 0.05)

# %%
pyod(*pyod_preprocess(fraudTrain, 0.2, 0.05))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.099863  0.950050  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.005624  0.855256  0.223803  0.768889  0.346693  0.814343
# 2      ECOD   0.005390  0.806971  0.151056  0.620000  0.242926  0.718401
# 3       GMM   0.079051  0.807193  0.136646  0.537778  0.217920  0.679568
# 4      HBOS   0.002512  0.949828  0.000000  0.000000  0.000000  0.499883
# 5   IForest   0.233243  0.909313  0.326066  0.764444  0.457143  0.840687
# 6      INNE   0.617690  0.900766  0.301075  0.746667  0.429119  0.827767
# 7       KDE  10.888934  0.905206  0.313653  0.755556  0.443286  0.834315
# 8       KNN   0.021715  0.894439  0.283865  0.731111  0.408950  0.817069
# 9      LODA   0.077641  0.949828  0.000000  0.000000  0.000000  0.499883
# 10      LOF   0.052920  0.662893  0.055040  0.355556  0.095323  0.517303
# 11      MAD   0.001756  0.963370  0.647783  0.584444  0.614486  0.783868
# 12      MCD   0.006619  0.908980  0.325142  0.764444  0.456233  0.840512
# 13    OCSVM  20.612067  0.905428  0.314233  0.755556  0.443864  0.834432
# 14      PCA   0.002859  0.667999  0.027520  0.164444  0.047149  0.429459
# 15      ROD   2.941879  0.688534  0.017609  0.095556  0.029737  0.407633
#
#     graph_based  pyod  throw_rate  train_size train_cols  train_frate  \
# 0         False  True         0.2       21021      [amt]     0.264307
# 1         False  True         0.2       21021      [amt]     0.264307
# 2         False  True         0.2       21021      [amt]     0.264307
# 3         False  True         0.2       21021      [amt]     0.264307
# 4         False  True         0.2       21021      [amt]     0.264307
# 5         False  True         0.2       21021      [amt]     0.264307
# 6         False  True         0.2       21021      [amt]     0.264307
# 7         False  True         0.2       21021      [amt]     0.264307
# 8         False  True         0.2       21021      [amt]     0.264307
# 9         False  True         0.2       21021      [amt]     0.264307
# 10        False  True         0.2       21021      [amt]     0.264307
# 11        False  True         0.2       21021      [amt]     0.264307
# 12        False  True         0.2       21021      [amt]     0.264307
# 13        False  True         0.2       21021      [amt]     0.264307
# 14        False  True         0.2       21021      [amt]     0.264307
# 15        False  True         0.2       21021      [amt]     0.264307
#
#     test_size  test_frate hyper_params
# 0        9009     0.04995         None
# 1        9009     0.04995         None
# 2        9009     0.04995         None
# 3        9009     0.04995         None
# 4        9009     0.04995         None
# 5        9009     0.04995         None
# 6        9009     0.04995         None
# 7        9009     0.04995         None
# 8        9009     0.04995         None
# 9        9009     0.04995         None
# 10       9009     0.04995         None
# 11       9009     0.04995         None
# 12       9009     0.04995         None
# 13       9009     0.04995         None
# 14       9009     0.04995         None
# 15       9009     0.04995         None

# %% [markdown]
# ## 시도4(0.2 / 0.005)

# %%
pyod(*pyod_preprocess(fraudTrain, 0.2, 0.005))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.120067  0.995005  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.005354  0.837829  0.024194  0.800000  0.046967  0.819009
# 2      ECOD   0.005339  0.805639  0.016988  0.666667  0.033131  0.736502
# 3       GMM   0.051490  0.804973  0.013636  0.533333  0.026593  0.669835
# 4      HBOS   0.002509  0.994672  0.000000  0.000000  0.000000  0.499833
# 5   IForest   0.242377  0.908092  0.042105  0.800000  0.080000  0.854317
# 6      INNE   0.605491  0.909535  0.042755  0.800000  0.081172  0.855042
# 7       KDE  11.031554  0.903985  0.040359  0.800000  0.076841  0.852253
# 8       KNN   0.021737  0.893884  0.033777  0.733333  0.064579  0.814012
# 9      LODA   0.071639  0.994672  0.000000  0.000000  0.000000  0.499833
# 10      LOF   0.051358  0.660340  0.004926  0.333333  0.009709  0.497657
# 11      MAD   0.001691  0.981352  0.144509  0.555556  0.229358  0.769523
# 12      MCD   0.006587  0.908314  0.042204  0.800000  0.080178  0.854429
# 13    OCSVM  19.988524  0.902875  0.039911  0.800000  0.076030  0.851696
# 14      PCA   0.002834  0.669331  0.002037  0.133333  0.004012  0.402677
# 15      ROD   3.424712  0.744145  0.000442  0.022222  0.000867  0.384996
#
#     graph_based  pyod  throw_rate  train_size train_cols  train_frate  \
# 0         False  True         0.2       21021      [amt]     0.283574
# 1         False  True         0.2       21021      [amt]     0.283574
# 2         False  True         0.2       21021      [amt]     0.283574
# 3         False  True         0.2       21021      [amt]     0.283574
# 4         False  True         0.2       21021      [amt]     0.283574
# 5         False  True         0.2       21021      [amt]     0.283574
# 6         False  True         0.2       21021      [amt]     0.283574
# 7         False  True         0.2       21021      [amt]     0.283574
# 8         False  True         0.2       21021      [amt]     0.283574
# 9         False  True         0.2       21021      [amt]     0.283574
# 10        False  True         0.2       21021      [amt]     0.283574
# 11        False  True         0.2       21021      [amt]     0.283574
# 12        False  True         0.2       21021      [amt]     0.283574
# 13        False  True         0.2       21021      [amt]     0.283574
# 14        False  True         0.2       21021      [amt]     0.283574
# 15        False  True         0.2       21021      [amt]     0.283574
#
#     test_size  test_frate hyper_params
# 0        9009    0.004995         None
# 1        9009    0.004995         None
# 2        9009    0.004995         None
# 3        9009    0.004995         None
# 4        9009    0.004995         None
# 5        9009    0.004995         None
# 6        9009    0.004995         None
# 7        9009    0.004995         None
# 8        9009    0.004995         None
# 9        9009    0.004995         None
# 10       9009    0.004995         None
# 11       9009    0.004995         None
# 12       9009    0.004995         None
# 13       9009    0.004995         None
# 14       9009    0.004995         None
# 15       9009    0.004995         None

# %% [markdown]
# ## 시도5(0.2 / 0.0005)

# %%
pyod(*pyod_preprocess(fraudTrain, 0.2, 0.0005))
# Out:
#       model       time       acc       pre   rec        f1       auc  \
# 0      ABOD   1.069119  0.999556  0.000000  0.00  0.000000  0.500000
# 1     COPOD   0.005346  0.835942  0.002027  0.75  0.004043  0.792990
# 2      ECOD   0.006209  0.805528  0.001710  0.75  0.003413  0.777776
# 3       GMM   0.082742  0.804529  0.000569  0.25  0.001134  0.527388
# 4      HBOS   0.002443  0.999223  0.000000  0.00  0.000000  0.499833
# 5   IForest   0.230697  0.908536  0.003632  0.75  0.007229  0.829303
# 6      INNE   0.609098  0.832723  0.001327  0.50  0.002647  0.666435
# 7       KDE  10.856316  0.904096  0.003464  0.75  0.006897  0.827082
# 8       KNN   0.021676  0.894439  0.002103  0.50  0.004188  0.697307
# 9      LODA   0.071447  0.999223  0.000000  0.00  0.000000  0.499833
# 10      LOF   0.050616  0.661672  0.000984  0.75  0.001965  0.705816
# 11      MAD   0.001689  0.983128  0.013158  0.50  0.025641  0.741671
# 12      MCD   0.006512  0.908425  0.003628  0.75  0.007220  0.829248
# 13    OCSVM  20.150592  0.902431  0.003405  0.75  0.006780  0.826249
# 14      PCA   0.002643  0.671329  0.000000  0.00  0.000000  0.335813
# 15      ROD   2.808707  0.748363  0.000000  0.00  0.000000  0.374348
#
#     graph_based  pyod  throw_rate  train_size train_cols  train_frate  \
# 0         False  True         0.2       21021      [amt]     0.285524
# 1         False  True         0.2       21021      [amt]     0.285524
# 2         False  True         0.2       21021      [amt]     0.285524
# 3         False  True         0.2       21021      [amt]     0.285524
# 4         False  True         0.2       21021      [amt]     0.285524
# 5         False  True         0.2       21021      [amt]     0.285524
# 6         False  True         0.2       21021      [amt]     0.285524
# 7         False  True         0.2       21021      [amt]     0.285524
# 8         False  True         0.2       21021      [amt]     0.285524
# 9         False  True         0.2       21021      [amt]     0.285524
# 10        False  True         0.2       21021      [amt]     0.285524
# 11        False  True         0.2       21021      [amt]     0.285524
# 12        False  True         0.2       21021      [amt]     0.285524
# 13        False  True         0.2       21021      [amt]     0.285524
# 14        False  True         0.2       21021      [amt]     0.285524
# 15        False  True         0.2       21021      [amt]     0.285524
#
#     test_size  test_frate hyper_params
# 0        9009    0.000444         None
# 1        9009    0.000444         None
# 2        9009    0.000444         None
# 3        9009    0.000444         None
# 4        9009    0.000444         None
# 5        9009    0.000444         None
# 6        9009    0.000444         None
# 7        9009    0.000444         None
# 8        9009    0.000444         None
# 9        9009    0.000444         None
# 10       9009    0.000444         None
# 11       9009    0.000444         None
# 12       9009    0.000444         None
# 13       9009    0.000444         None
# 14       9009    0.000444         None
# 15       9009    0.000444         None
