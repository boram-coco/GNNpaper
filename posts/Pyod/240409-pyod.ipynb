# %% [raw]
# ---
# title: "[Pyod] 실험계속돌리기"
# author: "김보람 "
# date: "04/09/2024"
# ---

# %% [markdown]
# 1. 4/9
#
# 2. 4/9 v2

# %% [markdown]
# ref: <https://pyod.readthedocs.io/en/latest/pyod.models.html#all-models>
#
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions_pyod2.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %% [markdown]
# # pyod_preprocess4(비율 다 같게)

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.05))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.018459  0.941625  0.415559  0.416945  0.416250  0.693068
# 1       GMM  0.018206  0.963703  0.639400  0.625751  0.632502  0.803605
# 2      HBOS  0.005152  0.949784  0.000000  0.000000  0.000000  0.499842
# 3   IForest  1.882320  0.964269  0.644898  0.632422  0.638599  0.807063
# 4      INNE  2.072049  0.963670  0.640690  0.619746  0.630044  0.800743
# 5       KNN  0.104469  0.959973  0.601782  0.585724  0.593644  0.782680
# 6      LODA  0.144588  0.949784  0.000000  0.000000  0.000000  0.499842
# 7       LOF  0.181420  0.897303  0.018237  0.020013  0.019084  0.481704
# 8       MCD  0.017638  0.963703  0.639400  0.625751  0.632502  0.803605
# 9       PCA  0.006440  0.945887  0.458333  0.462308  0.460312  0.716801
# 10      ROD  6.116452  0.900633  0.002012  0.002001  0.002007  0.474924
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.05       90090      [amt]     0.050028
# 1         False   pyod        0.05       90090      [amt]     0.050028
# 2         False   pyod        0.05       90090      [amt]     0.050028
# 3         False   pyod        0.05       90090      [amt]     0.050028
# 4         False   pyod        0.05       90090      [amt]     0.050028
# 5         False   pyod        0.05       90090      [amt]     0.050028
# 6         False   pyod        0.05       90090      [amt]     0.050028
# 7         False   pyod        0.05       90090      [amt]     0.050028
# 8         False   pyod        0.05       90090      [amt]     0.050028
# 9         False   pyod        0.05       90090      [amt]     0.050028
# 10        False   pyod        0.05       90090      [amt]     0.050028
#
#     test_size  test_frate hyper_params
# 0       30030    0.049917         None
# 1       30030    0.049917         None
# 2       30030    0.049917         None
# 3       30030    0.049917         None
# 4       30030    0.049917         None
# 5       30030    0.049917         None
# 6       30030    0.049917         None
# 7       30030    0.049917         None
# 8       30030    0.049917         None
# 9       30030    0.049917         None
# 10      30030    0.049917         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.04))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.022969  0.952475  0.404421  0.417450  0.410832  0.696020
# 1       GMM  0.038967  0.965448  0.561819  0.588591  0.574893  0.784808
# 2      HBOS  0.006372  0.959881  0.000000  0.000000  0.000000  0.499778
# 3   IForest  2.628140  0.965422  0.561935  0.584564  0.573026  0.782864
# 4      INNE  3.585891  0.965448  0.562541  0.582550  0.572371  0.781913
# 5       KNN  0.198542  0.963743  0.541640  0.563087  0.552155  0.771696
# 6      LODA  0.255740  0.959881  0.000000  0.000000  0.000000  0.499778
# 7       LOF  0.279460  0.914726  0.019652  0.023490  0.021400  0.487527
# 8       MCD  0.023501  0.965448  0.561819  0.588591  0.574893  0.784808
# 9       PCA  0.009270  0.957297  0.463852  0.486577  0.474943  0.731665
# 10      ROD  7.312386  0.921706  0.001376  0.001342  0.001359  0.480545
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.04      112612      [amt]     0.040102
# 1         False   pyod        0.04      112612      [amt]     0.040102
# 2         False   pyod        0.04      112612      [amt]     0.040102
# 3         False   pyod        0.04      112612      [amt]     0.040102
# 4         False   pyod        0.04      112612      [amt]     0.040102
# 5         False   pyod        0.04      112612      [amt]     0.040102
# 6         False   pyod        0.04      112612      [amt]     0.040102
# 7         False   pyod        0.04      112612      [amt]     0.040102
# 8         False   pyod        0.04      112612      [amt]     0.040102
# 9         False   pyod        0.04      112612      [amt]     0.040102
# 10        False   pyod        0.04      112612      [amt]     0.040102
#
#     test_size  test_frate hyper_params
# 0       37538    0.039693         None
# 1       37538    0.039693         None
# 2       37538    0.039693         None
# 3       37538    0.039693         None
# 4       37538    0.039693         None
# 5       37538    0.039693         None
# 6       37538    0.039693         None
# 7       37538    0.039693         None
# 8       37538    0.039693         None
# 9       37538    0.039693         None
# 10      37538    0.039693         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.03))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.030540  0.962977  0.381145  0.377333  0.379229  0.679202
# 1       GMM  0.036879  0.970390  0.506073  0.500000  0.503018  0.742461
# 2      HBOS  0.008019  0.969790  0.000000  0.000000  0.000000  0.499876
# 3   IForest  3.513902  0.970410  0.506415  0.500000  0.503187  0.742472
# 4      INNE  3.688303  0.970290  0.504354  0.502000  0.503174  0.743379
# 5       KNN  0.181093  0.969950  0.498670  0.500000  0.499334  0.742235
# 6      LODA  0.355441  0.969790  0.000000  0.000000  0.000000  0.499876
# 7       LOF  0.334967  0.935764  0.042667  0.053333  0.047407  0.508181
# 8       MCD  0.030296  0.970390  0.506073  0.500000  0.503018  0.742461
# 9       PCA  0.012220  0.968851  0.479808  0.467333  0.473489  0.725840
# 10      ROD  7.815375  0.939421  0.000652  0.000667  0.000659  0.484545
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.03      150150      [amt]      0.03001
# 1         False   pyod        0.03      150150      [amt]      0.03001
# 2         False   pyod        0.03      150150      [amt]      0.03001
# 3         False   pyod        0.03      150150      [amt]      0.03001
# 4         False   pyod        0.03      150150      [amt]      0.03001
# 5         False   pyod        0.03      150150      [amt]      0.03001
# 6         False   pyod        0.03      150150      [amt]      0.03001
# 7         False   pyod        0.03      150150      [amt]      0.03001
# 8         False   pyod        0.03      150150      [amt]      0.03001
# 9         False   pyod        0.03      150150      [amt]      0.03001
# 10        False   pyod        0.03      150150      [amt]      0.03001
#
#     test_size  test_frate hyper_params
# 0       50050     0.02997         None
# 1       50050     0.02997         None
# 2       50050     0.02997         None
# 3       50050     0.02997         None
# 4       50050     0.02997         None
# 5       50050     0.02997         None
# 6       50050     0.02997         None
# 7       50050     0.02997         None
# 8       50050     0.02997         None
# 9       50050     0.02997         None
# 10      50050     0.02997         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.02))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.045997  0.973680  0.341301  0.343124  0.342210  0.664821
# 1       GMM   0.089725  0.980300  0.506704  0.479306  0.492624  0.734903
# 2      HBOS   0.007989  0.979820  0.000000  0.000000  0.000000  0.499884
# 3   IForest   5.305866  0.980273  0.505990  0.479306  0.492287  0.734889
# 4      INNE   7.345861  0.980380  0.508859  0.479306  0.493640  0.734944
# 5       KNN   0.447924  0.977809  0.443624  0.441255  0.442436  0.714994
# 6      LODA   0.416931  0.979820  0.000000  0.000000  0.000000  0.499884
# 7       LOF   0.621124  0.960759  0.004788  0.004673  0.004730  0.492449
# 8       MCD   0.042279  0.980300  0.506704  0.479306  0.492624  0.734903
# 9       PCA   0.016963  0.980260  0.505682  0.475300  0.490021  0.732920
# 10      ROD  11.886595  0.959161  0.001272  0.001335  0.001303  0.489998
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.02      225225      [amt]     0.020016
# 1         False   pyod        0.02      225225      [amt]     0.020016
# 2         False   pyod        0.02      225225      [amt]     0.020016
# 3         False   pyod        0.02      225225      [amt]     0.020016
# 4         False   pyod        0.02      225225      [amt]     0.020016
# 5         False   pyod        0.02      225225      [amt]     0.020016
# 6         False   pyod        0.02      225225      [amt]     0.020016
# 7         False   pyod        0.02      225225      [amt]     0.020016
# 8         False   pyod        0.02      225225      [amt]     0.020016
# 9         False   pyod        0.02      225225      [amt]     0.020016
# 10        False   pyod        0.02      225225      [amt]     0.020016
#
#     test_size  test_frate hyper_params
# 0       75075    0.019953         None
# 1       75075    0.019953         None
# 2       75075    0.019953         None
# 3       75075    0.019953         None
# 4       75075    0.019953         None
# 5       75075    0.019953         None
# 6       75075    0.019953         None
# 7       75075    0.019953         None
# 8       75075    0.019953         None
# 9       75075    0.019953         None
# 10      75075    0.019953         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.01))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.092439  0.984356  0.224206  0.223762  0.223984  0.607935
# 1       GMM   0.087129  0.989411  0.474713  0.464686  0.469646  0.729723
# 2      HBOS   0.020368  0.989537  0.000000  0.000000  0.000000  0.499812
# 3   IForest   9.995700  0.989424  0.475354  0.464686  0.469960  0.729729
# 4      INNE  11.949565  0.984935  0.238262  0.224422  0.231135  0.608555
# 5       KNN   0.751256  0.987799  0.390614  0.373597  0.381916  0.683828
# 6      LODA   1.220203  0.989537  0.000000  0.000000  0.000000  0.499812
# 7       LOF   1.834617  0.980852  0.001466  0.001320  0.001389  0.496078
# 8       MCD   0.099866  0.989411  0.474713  0.464686  0.469646  0.729723
# 9       PCA   0.037454  0.989411  0.474713  0.464686  0.469646  0.729723
# 10      ROD  11.191975  0.978768  0.000597  0.000660  0.000627  0.494699
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.01      450450      [amt]      0.00997
# 1         False   pyod        0.01      450450      [amt]      0.00997
# 2         False   pyod        0.01      450450      [amt]      0.00997
# 3         False   pyod        0.01      450450      [amt]      0.00997
# 4         False   pyod        0.01      450450      [amt]      0.00997
# 5         False   pyod        0.01      450450      [amt]      0.00997
# 6         False   pyod        0.01      450450      [amt]      0.00997
# 7         False   pyod        0.01      450450      [amt]      0.00997
# 8         False   pyod        0.01      450450      [amt]      0.00997
# 9         False   pyod        0.01      450450      [amt]      0.00997
# 10        False   pyod        0.01      450450      [amt]      0.00997
#
#     test_size  test_frate hyper_params
# 0      150150     0.01009         None
# 1      150150     0.01009         None
# 2      150150     0.01009         None
# 3      150150     0.01009         None
# 4      150150     0.01009         None
# 5      150150     0.01009         None
# 6      150150     0.01009         None
# 7      150150     0.01009         None
# 8      150150     0.01009         None
# 9      150150     0.01009         None
# 10     150150     0.01009         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.00573))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.185352  0.990074  0.124831  0.124244  0.124537  0.559633
# 1       GMM   0.196944  0.993100  0.393738  0.396911  0.395318  0.696709
# 2      HBOS   0.035020  0.994043  0.000000  0.000000  0.000000  0.499862
# 3   IForest  18.934161  0.993089  0.391946  0.392210  0.392078  0.694366
# 4      INNE  22.542014  0.993104  0.394000  0.396911  0.395450  0.696711
# 5       KNN   2.293031  0.992242  0.316958  0.316320  0.316639  0.656212
# 6      LODA   1.799859  0.994043  0.000000  0.000000  0.000000  0.499862
# 7       LOF   2.320828  0.988231  0.001251  0.001343  0.001295  0.497607
# 8       MCD   0.147849  0.993100  0.393738  0.396911  0.395318  0.696709
# 9       PCA   0.046577  0.993100  0.393738  0.396911  0.395318  0.696709
# 10      ROD  13.266204  0.989933  0.000000  0.000000  0.000000  0.497795
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod     0.00573      786126      [amt]     0.005746
# 1         False   pyod     0.00573      786126      [amt]     0.005746
# 2         False   pyod     0.00573      786126      [amt]     0.005746
# 3         False   pyod     0.00573      786126      [amt]     0.005746
# 4         False   pyod     0.00573      786126      [amt]     0.005746
# 5         False   pyod     0.00573      786126      [amt]     0.005746
# 6         False   pyod     0.00573      786126      [amt]     0.005746
# 7         False   pyod     0.00573      786126      [amt]     0.005746
# 8         False   pyod     0.00573      786126      [amt]     0.005746
# 9         False   pyod     0.00573      786126      [amt]     0.005746
# 10        False   pyod     0.00573      786126      [amt]     0.005746
#
#     test_size  test_frate hyper_params
# 0      262042    0.005682         None
# 1      262042    0.005682         None
# 2      262042    0.005682         None
# 3      262042    0.005682         None
# 4      262042    0.005682         None
# 5      262042    0.005682         None
# 6      262042    0.005682         None
# 7      262042    0.005682         None
# 8      262042    0.005682         None
# 9      262042    0.005682         None
# 10     262042    0.005682         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.006))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.151684  0.989371  0.124752  0.124097  0.124424  0.559383
# 1       GMM   0.167509  0.992496  0.380310  0.370322  0.375250  0.683313
# 2      HBOS   0.033455  0.993662  0.000000  0.000000  0.000000  0.499873
# 3   IForest  17.080824  0.992523  0.377980  0.353907  0.365548  0.675170
# 4      INNE  21.824565  0.992484  0.377229  0.361129  0.369004  0.678739
# 5       KNN   1.317858  0.991684  0.308379  0.294813  0.301443  0.645382
# 6      LODA   1.825047  0.993662  0.000000  0.000000  0.000000  0.499873
# 7       LOF   2.652479  0.987908  0.000664  0.000657  0.000661  0.497305
# 8       MCD   0.141115  0.992496  0.380310  0.370322  0.375250  0.683313
# 9       PCA   0.049841  0.992496  0.380310  0.370322  0.375250  0.683313
# 10      ROD  13.219342  0.993826  0.000000  0.000000  0.000000  0.499956
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.006      750750      [amt]     0.005971
# 1         False   pyod       0.006      750750      [amt]     0.005971
# 2         False   pyod       0.006      750750      [amt]     0.005971
# 3         False   pyod       0.006      750750      [amt]     0.005971
# 4         False   pyod       0.006      750750      [amt]     0.005971
# 5         False   pyod       0.006      750750      [amt]     0.005971
# 6         False   pyod       0.006      750750      [amt]     0.005971
# 7         False   pyod       0.006      750750      [amt]     0.005971
# 8         False   pyod       0.006      750750      [amt]     0.005971
# 9         False   pyod       0.006      750750      [amt]     0.005971
# 10        False   pyod       0.006      750750      [amt]     0.005971
#
#     test_size  test_frate hyper_params
# 0      250250    0.006086         None
# 1      250250    0.006086         None
# 2      250250    0.006086         None
# 3      250250    0.006086         None
# 4      250250    0.006086         None
# 5      250250    0.006086         None
# 6      250250    0.006086         None
# 7      250250    0.006086         None
# 8      250250    0.006086         None
# 9      250250    0.006086         None
# 10     250250    0.006086         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.007))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.131109  0.988182  0.168297  0.169960  0.169125  0.581987
# 1       GMM   0.134698  0.991883  0.430182  0.452569  0.441091  0.724148
# 2      HBOS   0.020757  0.992569  0.000000  0.000000  0.000000  0.499822
# 3   IForest  14.001544  0.991879  0.428205  0.440053  0.434048  0.717932
# 4      INNE  16.858406  0.991995  0.433177  0.424901  0.428999  0.710469
# 5       KNN   1.342403  0.990918  0.358179  0.357708  0.357943  0.676570
# 6      LODA   1.506973  0.992569  0.000000  0.000000  0.000000  0.499822
# 7       LOF   1.699454  0.986270  0.000700  0.000659  0.000679  0.496977
# 8       MCD   0.122125  0.991883  0.430182  0.452569  0.441091  0.724148
# 9       PCA   0.038957  0.991883  0.430182  0.452569  0.441091  0.724148
# 10      ROD  11.968887  0.984093  0.000527  0.000659  0.000586  0.495881
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.007      643500      [amt]     0.006974
# 1         False   pyod       0.007      643500      [amt]     0.006974
# 2         False   pyod       0.007      643500      [amt]     0.006974
# 3         False   pyod       0.007      643500      [amt]     0.006974
# 4         False   pyod       0.007      643500      [amt]     0.006974
# 5         False   pyod       0.007      643500      [amt]     0.006974
# 6         False   pyod       0.007      643500      [amt]     0.006974
# 7         False   pyod       0.007      643500      [amt]     0.006974
# 8         False   pyod       0.007      643500      [amt]     0.006974
# 9         False   pyod       0.007      643500      [amt]     0.006974
# 10        False   pyod       0.007      643500      [amt]     0.006974
#
#     test_size  test_frate hyper_params
# 0      214500    0.007077         None
# 1      214500    0.007077         None
# 2      214500    0.007077         None
# 3      214500    0.007077         None
# 4      214500    0.007077         None
# 5      214500    0.007077         None
# 6      214500    0.007077         None
# 7      214500    0.007077         None
# 8      214500    0.007077         None
# 9      214500    0.007077         None
# 10     214500    0.007077         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.008))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.116639  0.987106  0.189723  0.194858  0.192256  0.594126
# 1       GMM   0.234154  0.991145  0.437073  0.432341  0.434694  0.713961
# 2      HBOS   0.026671  0.991784  0.000000  0.000000  0.000000  0.499828
# 3   IForest  12.237301  0.991092  0.432825  0.422869  0.427789  0.709235
# 4      INNE  14.147942  0.986627  0.149457  0.148850  0.149153  0.571063
# 5       KNN   0.896999  0.990015  0.357963  0.337618  0.347493  0.666406
# 6      LODA   1.356931  0.991784  0.000000  0.000000  0.000000  0.499828
# 7       LOF   1.886451  0.985007  0.000000  0.000000  0.000000  0.496413
# 8       MCD   0.115112  0.991145  0.437073  0.432341  0.434694  0.713961
# 9       PCA   0.034219  0.991145  0.437073  0.432341  0.434694  0.713961
# 10      ROD  13.046033  0.980862  0.000000  0.000000  0.000000  0.494324
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.008      563062      [amt]     0.008042
# 1         False   pyod       0.008      563062      [amt]     0.008042
# 2         False   pyod       0.008      563062      [amt]     0.008042
# 3         False   pyod       0.008      563062      [amt]     0.008042
# 4         False   pyod       0.008      563062      [amt]     0.008042
# 5         False   pyod       0.008      563062      [amt]     0.008042
# 6         False   pyod       0.008      563062      [amt]     0.008042
# 7         False   pyod       0.008      563062      [amt]     0.008042
# 8         False   pyod       0.008      563062      [amt]     0.008042
# 9         False   pyod       0.008      563062      [amt]     0.008042
# 10        False   pyod       0.008      563062      [amt]     0.008042
#
#     test_size  test_frate hyper_params
# 0      187688    0.007875         None
# 1      187688    0.007875         None
# 2      187688    0.007875         None
# 3      187688    0.007875         None
# 4      187688    0.007875         None
# 5      187688    0.007875         None
# 6      187688    0.007875         None
# 7      187688    0.007875         None
# 8      187688    0.007875         None
# 9      187688    0.007875         None
# 10     187688    0.007875         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.009))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.102200  0.986076  0.205654  0.195302  0.200344  0.594252
# 1       GMM   0.133087  0.990290  0.458493  0.481879  0.469895  0.738375
# 2      HBOS   0.017601  0.990715  0.000000  0.000000  0.000000  0.499822
# 3   IForest  10.991961  0.990350  0.461190  0.478523  0.469697  0.736743
# 4      INNE  12.630279  0.990326  0.460154  0.480537  0.470125  0.737728
# 5       KNN   0.768636  0.988815  0.377124  0.387248  0.382119  0.690742
# 6      LODA   1.153257  0.990715  0.000000  0.000000  0.000000  0.499822
# 7       LOF   1.696732  0.982144  0.000671  0.000671  0.000671  0.495830
# 8       MCD   0.086937  0.990290  0.458493  0.481879  0.469895  0.738375
# 9       PCA   0.029609  0.990290  0.458493  0.481879  0.469895  0.738375
# 10      ROD  14.697056  0.984500  0.000000  0.000000  0.000000  0.496686
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.009      500499      [amt]     0.009023
# 1         False   pyod       0.009      500499      [amt]     0.009023
# 2         False   pyod       0.009      500499      [amt]     0.009023
# 3         False   pyod       0.009      500499      [amt]     0.009023
# 4         False   pyod       0.009      500499      [amt]     0.009023
# 5         False   pyod       0.009      500499      [amt]     0.009023
# 6         False   pyod       0.009      500499      [amt]     0.009023
# 7         False   pyod       0.009      500499      [amt]     0.009023
# 8         False   pyod       0.009      500499      [amt]     0.009023
# 9         False   pyod       0.009      500499      [amt]     0.009023
# 10        False   pyod       0.009      500499      [amt]     0.009023
#
#     test_size  test_frate hyper_params
# 0      166834    0.008931         None
# 1      166834    0.008931         None
# 2      166834    0.008931         None
# 3      166834    0.008931         None
# 4      166834    0.008931         None
# 5      166834    0.008931         None
# 6      166834    0.008931         None
# 7      166834    0.008931         None
# 8      166834    0.008931         None
# 9      166834    0.008931         None
# 10     166834    0.008931         None

# %% [markdown]
# # pyod_preprocess3: 비율 다 다르게 n

# %%
pyod(*pyod_preprocess3(fraudTrain, 10))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      HBOS  0.006443  0.998152  0.000000  0.000000  0.000000  0.499769
# 1   IForest  0.575482  0.688292  0.002837  0.638889  0.005650  0.663625
# 2      INNE  0.456607  0.605282  0.001659  0.472222  0.003305  0.538845
# 3       KDE  2.303776  0.765641  0.004260  0.722222  0.008470  0.743962
# 4       KNN  0.012869  0.737112  0.003799  0.722222  0.007558  0.729677
# 5      LODA  0.032645  0.998152  0.000000  0.000000  0.000000  0.499769
# 6       LOF  0.021129  0.442305  0.001518  0.611111  0.003028  0.526591
# 7       MCD  0.005205  0.780041  0.004538  0.722222  0.009020  0.751172
# 8     OCSVM  5.913461  0.681939  0.003021  0.694444  0.006016  0.688183
# 9       PCA  0.003100  0.221576  0.000495  0.277778  0.000988  0.249638
# 10      ROD  2.317307  0.499326  0.000693  0.250000  0.001382  0.374836
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.129752        9009      [amt]     0.499833
# 1         False   pyod    0.129752        9009      [amt]     0.499833
# 2         False   pyod    0.129752        9009      [amt]     0.499833
# 3         False   pyod    0.129752        9009      [amt]     0.499833
# 4         False   pyod    0.129752        9009      [amt]     0.499833
# 5         False   pyod    0.129752        9009      [amt]     0.499833
# 6         False   pyod    0.129752        9009      [amt]     0.499833
# 7         False   pyod    0.129752        9009      [amt]     0.499833
# 8         False   pyod    0.129752        9009      [amt]     0.499833
# 9         False   pyod    0.129752        9009      [amt]     0.499833
# 10        False   pyod    0.129752        9009      [amt]     0.499833
#
#     test_size  test_frate hyper_params
# 0       25973    0.001386         None
# 1       25973    0.001386         None
# 2       25973    0.001386         None
# 3       25973    0.001386         None
# 4       25973    0.001386         None
# 5       25973    0.001386         None
# 6       25973    0.001386         None
# 7       25973    0.001386         None
# 8       25973    0.001386         None
# 9       25973    0.001386         None
# 10      25973    0.001386         None

# %%
pyod(*pyod_preprocess3(fraudTrain, 9))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      HBOS  0.002710  0.998061  0.000000  0.000000  0.000000  0.499913
# 1   IForest  0.373593  0.776958  0.006640  0.843137  0.013176  0.809989
# 2      INNE  0.362749  0.488157  0.001624  0.470588  0.003237  0.479388
# 3       KDE  2.302988  0.771348  0.006478  0.843137  0.012857  0.807179
# 4       KNN  0.012862  0.732530  0.005414  0.823529  0.010758  0.777949
# 5      LODA  0.032460  0.998061  0.000000  0.000000  0.000000  0.499913
# 6       LOF  0.021190  0.425064  0.001626  0.529412  0.003242  0.477146
# 7       MCD  0.005226  0.776439  0.006625  0.843137  0.013146  0.809729
# 8     OCSVM  3.961363  0.681211  0.004653  0.843137  0.009255  0.762031
# 9       PCA  0.002726  0.224427  0.000358  0.156863  0.000714  0.190705
# 10      ROD  1.205790  0.498719  0.000485  0.137255  0.000966  0.318307
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.120173        9009      [amt]     0.499722
# 1         False   pyod    0.120173        9009      [amt]     0.499722
# 2         False   pyod    0.120173        9009      [amt]     0.499722
# 3         False   pyod    0.120173        9009      [amt]     0.499722
# 4         False   pyod    0.120173        9009      [amt]     0.499722
# 5         False   pyod    0.120173        9009      [amt]     0.499722
# 6         False   pyod    0.120173        9009      [amt]     0.499722
# 7         False   pyod    0.120173        9009      [amt]     0.499722
# 8         False   pyod    0.120173        9009      [amt]     0.499722
# 9         False   pyod    0.120173        9009      [amt]     0.499722
# 10        False   pyod    0.120173        9009      [amt]     0.499722
#
#     test_size  test_frate hyper_params
# 0       28878    0.001766         None
# 1       28878    0.001766         None
# 2       28878    0.001766         None
# 3       28878    0.001766         None
# 4       28878    0.001766         None
# 5       28878    0.001766         None
# 6       28878    0.001766         None
# 7       28878    0.001766         None
# 8       28878    0.001766         None
# 9       28878    0.001766         None
# 10      28878    0.001766         None

# %%
pyod(*pyod_preprocess3(fraudTrain, 5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 pyod(*pyod_preprocess3(fraudTrain, 5))
#
# File ~/Dropbox/GNNpaper/posts/functions_pyod2.py:295, in pyod_preprocess3(fraudTrain, n)
#     279     throw_rate = df.is_fraud.mean()
#     280     fraud_ratio = df_tr.is_fraud.mean()
#     281     predictors = {
#     282 #######    'ABOD': ABOD(contamination=fraud_ratio),
#     283 #    'ALAD': ALAD(contamination=fraud_ratio),
#     284 #    'AnoGAN': AnoGAN(contamination=fraud_ratio),
#     285 #    'AutoEncoder':AutoEncoder(contamination=fraud_ratio),
#     286 ##    'CBLOF': CBLOF(contamination=fraud_ratio,n_clusters=2),
#     287 ##    'COF': COF(contamination=fraud_ratio),
#     288 ##    'CD': CD(contamination=fraud_ratio),
#     289 #######    'COPOD': COPOD(contamination=fraud_ratio),
#     290 #    'DeepSVDD': DeepSVDD(contamination=fraud_ratio),
#     291 #    'DIF': DIF(contamination=fraud_ratio),
#     292 #    'ECOD': ECOD(contamination=fraud_ratio),
#     293 #    'FeatureBagging': FeatureBagging(contamination=fraud_ratio),
#     294 #    'GMM': GMM(contamination=fraud_ratio),
# --> 295     'HBOS': HBOS(contamination=fraud_ratio),
#     296     'IForest': IForest(contamination=fraud_ratio),
#     297     'INNE': INNE(contamination=fraud_ratio),
#     298     'KDE': KDE(contamination=fraud_ratio),
#     299     'KNN': KNN(contamination=fraud_ratio),
#     300 ####    'KPCA': KPCA(contamination=fraud_ratio),
#     301 #    'PyODKernelPCA': PyODKernelPCA(contamination=fraud_ratio),
#     302 ##    'LMDD': LMDD(contamination=fraud_ratio),
#     303     'LODA': LODA(contamination=fraud_ratio),
#     304     'LOF': LOF(contamination=fraud_ratio),
#     305 ####    'LOCI': LOCI(contamination=fraud_ratio),
#     306 #    'LUNAR': LUNAR(contamination=fraud_ratio),
#     307     'LODA': LODA(contamination=fraud_ratio),
#     308 #    'LSCP': LSCP(contamination=fraud_ratio),
#     309 ####    'MAD': MAD(contamination=fraud_ratio),
#     310     'MCD': MCD(contamination=fraud_ratio),
#     311 #    'MO_GAAL': MO_GAAL(contamination=fraud_ratio),
#     312     'OCSVM': OCSVM(contamination=fraud_ratio),
#     313     'PCA': PCA(contamination=fraud_ratio),
#     314 ###    'QMCD': QMCD(contamination=fraud_ratio),
#     315 ####    'RGraph': RGraph(contamination=fraud_ratio),
#     316     'ROD': ROD(contamination=fraud_ratio),
#     317 ##    'Sampling': Sampling(contamination=fraud_ratio),
#     318 ##   'SOD': SOD(contamination=fraud_ratio),
#     319 #    'SO_GAAL': SO_GAAL(contamination=fraud_ratio),
#     320 ####    'SOS': SOS(contamination=fraud_ratio),
#     321 #    'SUOD': SUOD(contamination=fraud_ratio),
#     322 #    'VAE': VAE(contamination=fraud_ratio),
#     323 #    'XGBOD': XGBOD(contamination=fraud_ratio),
#     324 }
#     325     return X, XX, y, yy, predictors, throw_rate
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pyod/models/hbos.py:77, in HBOS.__init__(self, n_bins, alpha, tol, contamination)
#      76 def __init__(self, n_bins=10, alpha=0.1, tol=0.5, contamination=0.1):
# ---> 77     super(HBOS, self).__init__(contamination=contamination)
#      78     self.n_bins = n_bins
#      79     self.alpha = alpha
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pyod/models/base.py:70, in BaseDetector.__init__(self, contamination)
#      67 if (isinstance(contamination, (float, int))):
#      69     if not (0. < contamination <= 0.5):
# ---> 70         raise ValueError("contamination must be in (0, 0.5], "
#      71                          "got: %f" % contamination)
#      73 # allow arbitrary input such as PyThreshld object
#      74 self.contamination = contamination
#
# ValueError: contamination must be in (0, 0.5], got: 0.503608

# %%
pyod(*pyod_preprocess3(fraudTrain, 4))

# %%
pyod(*pyod_preprocess3(fraudTrain, 2))

# %% [markdown]
# # pyod_preproecess10: 비율 다르게 test_size정할수 잇음

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.3, 0.05))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.303755  0.950050  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.005141  0.749417  0.138138  0.766667  0.234097  0.757589
# 2      ECOD   0.004929  0.719447  0.116768  0.703333  0.200285  0.711814
# 3       GMM   0.028621  0.706294  0.093785  0.563333  0.160799  0.638572
# 4      HBOS   0.002344  0.949717  0.000000  0.000000  0.000000  0.499825
# 5   IForest   0.493717  0.821012  0.185726  0.763333  0.298761  0.793689
# 6      INNE   0.507107  0.684815  0.082328  0.523333  0.142275  0.608319
# 7       KDE   5.360161  0.845155  0.213115  0.780000  0.334764  0.814290
# 8       KNN   0.021141  0.816683  0.176755  0.730000  0.284600  0.775620
# 9      LODA   0.046021  0.949717  0.000000  0.000000  0.000000  0.499825
# 10      LOF   0.035127  0.511988  0.051483  0.503333  0.093412  0.507888
# 11      MCD   0.005731  0.847486  0.215867  0.780000  0.338150  0.815517
# 12    OCSVM  13.213274  0.808525  0.171561  0.740000  0.278545  0.776064
# 13      PCA   0.003477  0.454545  0.020619  0.213333  0.037603  0.340280
# 14      ROD   2.937969  0.583417  0.027062  0.210000  0.047945  0.406525
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.3       14014      [amt]     0.407164
# 1         False   pyod         0.3       14014      [amt]     0.407164
# 2         False   pyod         0.3       14014      [amt]     0.407164
# 3         False   pyod         0.3       14014      [amt]     0.407164
# 4         False   pyod         0.3       14014      [amt]     0.407164
# 5         False   pyod         0.3       14014      [amt]     0.407164
# 6         False   pyod         0.3       14014      [amt]     0.407164
# 7         False   pyod         0.3       14014      [amt]     0.407164
# 8         False   pyod         0.3       14014      [amt]     0.407164
# 9         False   pyod         0.3       14014      [amt]     0.407164
# 10        False   pyod         0.3       14014      [amt]     0.407164
# 11        False   pyod         0.3       14014      [amt]     0.407164
# 12        False   pyod         0.3       14014      [amt]     0.407164
# 13        False   pyod         0.3       14014      [amt]     0.407164
# 14        False   pyod         0.3       14014      [amt]     0.407164
#
#     test_size  test_frate hyper_params
# 0        6006     0.04995         None
# 1        6006     0.04995         None
# 2        6006     0.04995         None
# 3        6006     0.04995         None
# 4        6006     0.04995         None
# 5        6006     0.04995         None
# 6        6006     0.04995         None
# 7        6006     0.04995         None
# 8        6006     0.04995         None
# 9        6006     0.04995         None
# 10       6006     0.04995         None
# 11       6006     0.04995         None
# 12       6006     0.04995         None
# 13       6006     0.04995         None
# 14       6006     0.04995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.3, 0.005))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.327881  0.995005  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.005117  0.722611  0.015976  0.900000  0.031395  0.810860
# 2      ECOD   0.004961  0.712121  0.013738  0.800000  0.027012  0.755840
# 3       GMM   0.040546  0.703130  0.010609  0.633333  0.020868  0.668407
# 4      HBOS   0.011508  0.994672  0.000000  0.000000  0.000000  0.499833
# 5   IForest   0.563816  0.836996  0.026919  0.900000  0.052275  0.868340
# 6      INNE   0.513023  0.619214  0.007420  0.566667  0.014649  0.593072
# 7       KDE   5.253528  0.835498  0.026680  0.900000  0.051823  0.867587
# 8       KNN   0.021494  0.805361  0.020219  0.800000  0.039441  0.802694
# 9      LODA   0.044922  0.994672  0.000000  0.000000  0.000000  0.499833
# 10      LOF   0.035639  0.494339  0.003632  0.366667  0.007192  0.430823
# 11      MCD   0.005897  0.835997  0.026759  0.900000  0.051973  0.867838
# 12    OCSVM  13.451926  0.776557  0.019062  0.866667  0.037303  0.821386
# 13      PCA   0.003347  0.419414  0.000866  0.100000  0.001718  0.260509
# 14      ROD   2.973712  0.561605  0.001150  0.100000  0.002274  0.331961
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.3       14014      [amt]     0.426431
# 1         False   pyod         0.3       14014      [amt]     0.426431
# 2         False   pyod         0.3       14014      [amt]     0.426431
# 3         False   pyod         0.3       14014      [amt]     0.426431
# 4         False   pyod         0.3       14014      [amt]     0.426431
# 5         False   pyod         0.3       14014      [amt]     0.426431
# 6         False   pyod         0.3       14014      [amt]     0.426431
# 7         False   pyod         0.3       14014      [amt]     0.426431
# 8         False   pyod         0.3       14014      [amt]     0.426431
# 9         False   pyod         0.3       14014      [amt]     0.426431
# 10        False   pyod         0.3       14014      [amt]     0.426431
# 11        False   pyod         0.3       14014      [amt]     0.426431
# 12        False   pyod         0.3       14014      [amt]     0.426431
# 13        False   pyod         0.3       14014      [amt]     0.426431
# 14        False   pyod         0.3       14014      [amt]     0.426431
#
#     test_size  test_frate hyper_params
# 0        6006    0.004995         None
# 1        6006    0.004995         None
# 2        6006    0.004995         None
# 3        6006    0.004995         None
# 4        6006    0.004995         None
# 5        6006    0.004995         None
# 6        6006    0.004995         None
# 7        6006    0.004995         None
# 8        6006    0.004995         None
# 9        6006    0.004995         None
# 10       6006    0.004995         None
# 11       6006    0.004995         None
# 12       6006    0.004995         None
# 13       6006    0.004995         None
# 14       6006    0.004995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.05))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.856662  0.950050  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.006642  0.855256  0.223803  0.768889  0.346693  0.814343
# 2      ECOD   0.006369  0.806971  0.151056  0.620000  0.242926  0.718401
# 3       GMM   0.036913  0.807193  0.136646  0.537778  0.217920  0.679568
# 4      HBOS   0.002596  0.949828  0.000000  0.000000  0.000000  0.499883
# 5   IForest   0.731305  0.909313  0.326066  0.764444  0.457143  0.840687
# 6      INNE   0.744110  0.870574  0.230422  0.680000  0.344207  0.780297
# 7       KDE  13.011977  0.905206  0.313653  0.755556  0.443286  0.834315
# 8       KNN   0.030093  0.894439  0.283865  0.731111  0.408950  0.817069
# 9      LODA   0.058603  0.949828  0.000000  0.000000  0.000000  0.499883
# 10      LOF   0.049695  0.662893  0.055040  0.355556  0.095323  0.517303
# 11      MCD   0.007552  0.908980  0.325142  0.764444  0.456233  0.840512
# 12    OCSVM  31.389795  0.905428  0.314233  0.755556  0.443864  0.834432
# 13      PCA   0.003757  0.667999  0.027520  0.164444  0.047149  0.429459
# 14      ROD   4.168068  0.688534  0.017609  0.095556  0.029737  0.407633
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.2       21021      [amt]     0.264307
# 1         False   pyod         0.2       21021      [amt]     0.264307
# 2         False   pyod         0.2       21021      [amt]     0.264307
# 3         False   pyod         0.2       21021      [amt]     0.264307
# 4         False   pyod         0.2       21021      [amt]     0.264307
# 5         False   pyod         0.2       21021      [amt]     0.264307
# 6         False   pyod         0.2       21021      [amt]     0.264307
# 7         False   pyod         0.2       21021      [amt]     0.264307
# 8         False   pyod         0.2       21021      [amt]     0.264307
# 9         False   pyod         0.2       21021      [amt]     0.264307
# 10        False   pyod         0.2       21021      [amt]     0.264307
# 11        False   pyod         0.2       21021      [amt]     0.264307
# 12        False   pyod         0.2       21021      [amt]     0.264307
# 13        False   pyod         0.2       21021      [amt]     0.264307
# 14        False   pyod         0.2       21021      [amt]     0.264307
#
#     test_size  test_frate hyper_params
# 0        9009     0.04995         None
# 1        9009     0.04995         None
# 2        9009     0.04995         None
# 3        9009     0.04995         None
# 4        9009     0.04995         None
# 5        9009     0.04995         None
# 6        9009     0.04995         None
# 7        9009     0.04995         None
# 8        9009     0.04995         None
# 9        9009     0.04995         None
# 10       9009     0.04995         None
# 11       9009     0.04995         None
# 12       9009     0.04995         None
# 13       9009     0.04995         None
# 14       9009     0.04995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.005))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.883506  0.995005  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.006611  0.837829  0.024194  0.800000  0.046967  0.819009
# 2      ECOD   0.006325  0.805639  0.016988  0.666667  0.033131  0.736502
# 3       GMM   0.033047  0.804973  0.013636  0.533333  0.026593  0.669835
# 4      HBOS   0.002670  0.994672  0.000000  0.000000  0.000000  0.499833
# 5   IForest   0.666340  0.908980  0.042503  0.800000  0.080717  0.854763
# 6      INNE   0.742284  0.909646  0.042806  0.800000  0.081264  0.855098
# 7       KDE  12.345613  0.903985  0.040359  0.800000  0.076841  0.852253
# 8       KNN   0.035549  0.893884  0.033777  0.733333  0.064579  0.814012
# 9      LODA   0.099662  0.994672  0.000000  0.000000  0.000000  0.499833
# 10      LOF   0.050844  0.660340  0.004926  0.333333  0.009709  0.497657
# 11      MCD   0.012257  0.908314  0.042204  0.800000  0.080178  0.854429
# 12    OCSVM  33.079905  0.902875  0.039911  0.800000  0.076030  0.851696
# 13      PCA   0.003220  0.669331  0.002037  0.133333  0.004012  0.402677
# 14      ROD   8.804143  0.744145  0.000442  0.022222  0.000867  0.384996
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.2       21021      [amt]     0.283574
# 1         False   pyod         0.2       21021      [amt]     0.283574
# 2         False   pyod         0.2       21021      [amt]     0.283574
# 3         False   pyod         0.2       21021      [amt]     0.283574
# 4         False   pyod         0.2       21021      [amt]     0.283574
# 5         False   pyod         0.2       21021      [amt]     0.283574
# 6         False   pyod         0.2       21021      [amt]     0.283574
# 7         False   pyod         0.2       21021      [amt]     0.283574
# 8         False   pyod         0.2       21021      [amt]     0.283574
# 9         False   pyod         0.2       21021      [amt]     0.283574
# 10        False   pyod         0.2       21021      [amt]     0.283574
# 11        False   pyod         0.2       21021      [amt]     0.283574
# 12        False   pyod         0.2       21021      [amt]     0.283574
# 13        False   pyod         0.2       21021      [amt]     0.283574
# 14        False   pyod         0.2       21021      [amt]     0.283574
#
#     test_size  test_frate hyper_params
# 0        9009    0.004995         None
# 1        9009    0.004995         None
# 2        9009    0.004995         None
# 3        9009    0.004995         None
# 4        9009    0.004995         None
# 5        9009    0.004995         None
# 6        9009    0.004995         None
# 7        9009    0.004995         None
# 8        9009    0.004995         None
# 9        9009    0.004995         None
# 10       9009    0.004995         None
# 11       9009    0.004995         None
# 12       9009    0.004995         None
# 13       9009    0.004995         None
# 14       9009    0.004995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.0005))
# Out:
#       model       time       acc       pre   rec        f1       auc  \
# 0      ABOD   1.510842  0.999556  0.000000  0.00  0.000000  0.500000
# 1     COPOD   0.007682  0.835942  0.002027  0.75  0.004043  0.792990
# 2      ECOD   0.010050  0.805528  0.001710  0.75  0.003413  0.777776
# 3       GMM   0.104791  0.804529  0.000569  0.25  0.001134  0.527388
# 4      HBOS   0.003298  0.999223  0.000000  0.00  0.000000  0.499833
# 5   IForest   1.075834  0.906427  0.003550  0.75  0.007067  0.828248
# 6      INNE   0.988767  0.848485  0.002195  0.75  0.004376  0.799264
# 7       KDE  12.620237  0.904096  0.003464  0.75  0.006897  0.827082
# 8       KNN   0.022917  0.894439  0.002103  0.50  0.004188  0.697307
# 9      LODA   0.058383  0.999223  0.000000  0.00  0.000000  0.499833
# 10      LOF   0.048166  0.661672  0.000984  0.75  0.001965  0.705816
# 11      MCD   0.006947  0.908425  0.003628  0.75  0.007220  0.829248
# 12    OCSVM  21.518104  0.902431  0.003405  0.75  0.006780  0.826249
# 13      PCA   0.003192  0.671329  0.000000  0.00  0.000000  0.335813
# 14      ROD   2.839865  0.748363  0.000000  0.00  0.000000  0.374348
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.2       21021      [amt]     0.285524
# 1         False   pyod         0.2       21021      [amt]     0.285524
# 2         False   pyod         0.2       21021      [amt]     0.285524
# 3         False   pyod         0.2       21021      [amt]     0.285524
# 4         False   pyod         0.2       21021      [amt]     0.285524
# 5         False   pyod         0.2       21021      [amt]     0.285524
# 6         False   pyod         0.2       21021      [amt]     0.285524
# 7         False   pyod         0.2       21021      [amt]     0.285524
# 8         False   pyod         0.2       21021      [amt]     0.285524
# 9         False   pyod         0.2       21021      [amt]     0.285524
# 10        False   pyod         0.2       21021      [amt]     0.285524
# 11        False   pyod         0.2       21021      [amt]     0.285524
# 12        False   pyod         0.2       21021      [amt]     0.285524
# 13        False   pyod         0.2       21021      [amt]     0.285524
# 14        False   pyod         0.2       21021      [amt]     0.285524
#
#     test_size  test_frate hyper_params
# 0        9009    0.000444         None
# 1        9009    0.000444         None
# 2        9009    0.000444         None
# 3        9009    0.000444         None
# 4        9009    0.000444         None
# 5        9009    0.000444         None
# 6        9009    0.000444         None
# 7        9009    0.000444         None
# 8        9009    0.000444         None
# 9        9009    0.000444         None
# 10       9009    0.000444         None
# 11       9009    0.000444         None
# 12       9009    0.000444         None
# 13       9009    0.000444         None
# 14       9009    0.000444         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.1, 0.05))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   2.107340  0.950050  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.009632  0.940004  0.442246  0.770000  0.561816  0.859471
# 2      ECOD   0.009768  0.900155  0.251245  0.504444  0.335427  0.712702
# 3       GMM   0.030952  0.955045  0.535322  0.757778  0.627415  0.861597
# 4      HBOS   0.003395  0.949495  0.000000  0.000000  0.000000  0.499708
# 5   IForest   1.047862  0.955045  0.534830  0.767778  0.630474  0.866334
# 6      INNE   1.031519  0.952048  0.513761  0.746667  0.608696  0.854756
# 7       KDE  45.811256  0.947441  0.482682  0.727778  0.580416  0.843384
# 8       KNN   0.048709  0.941947  0.446715  0.680000  0.539207  0.817860
# 9      LODA   0.104360  0.949495  0.000000  0.000000  0.000000  0.499708
# 10      LOF   0.101561  0.821567  0.075541  0.228889  0.113593  0.540809
# 11      MCD   0.010722  0.955433  0.537802  0.766667  0.632158  0.866012
# 12    OCSVM  97.442385  0.945943  0.473188  0.725556  0.572807  0.841543
# 13      PCA   0.004443  0.890054  0.195493  0.385556  0.259439  0.651067
# 14      ROD   4.021049  0.822233  0.001299  0.003333  0.001870  0.434311
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.1       42042      [amt]      0.12145
# 1         False   pyod         0.1       42042      [amt]      0.12145
# 2         False   pyod         0.1       42042      [amt]      0.12145
# 3         False   pyod         0.1       42042      [amt]      0.12145
# 4         False   pyod         0.1       42042      [amt]      0.12145
# 5         False   pyod         0.1       42042      [amt]      0.12145
# 6         False   pyod         0.1       42042      [amt]      0.12145
# 7         False   pyod         0.1       42042      [amt]      0.12145
# 8         False   pyod         0.1       42042      [amt]      0.12145
# 9         False   pyod         0.1       42042      [amt]      0.12145
# 10        False   pyod         0.1       42042      [amt]      0.12145
# 11        False   pyod         0.1       42042      [amt]      0.12145
# 12        False   pyod         0.1       42042      [amt]      0.12145
# 13        False   pyod         0.1       42042      [amt]      0.12145
# 14        False   pyod         0.1       42042      [amt]      0.12145
#
#     test_size  test_frate hyper_params
# 0       18018     0.04995         None
# 1       18018     0.04995         None
# 2       18018     0.04995         None
# 3       18018     0.04995         None
# 4       18018     0.04995         None
# 5       18018     0.04995         None
# 6       18018     0.04995         None
# 7       18018     0.04995         None
# 8       18018     0.04995         None
# 9       18018     0.04995         None
# 10      18018     0.04995         None
# 11      18018     0.04995         None
# 12      18018     0.04995         None
# 13      18018     0.04995         None
# 14      18018     0.04995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.3, 0.005))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.326669  0.995005  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.005198  0.722611  0.015976  0.900000  0.031395  0.810860
# 2      ECOD   0.004936  0.712121  0.013738  0.800000  0.027012  0.755840
# 3       GMM   0.025235  0.703130  0.010609  0.633333  0.020868  0.668407
# 4      HBOS   0.002372  0.994672  0.000000  0.000000  0.000000  0.499833
# 5   IForest   0.536821  0.796703  0.021687  0.900000  0.042353  0.848092
# 6      INNE   0.518270  0.808358  0.019709  0.766667  0.038429  0.787617
# 7       KDE   5.262691  0.835498  0.026680  0.900000  0.051823  0.867587
# 8       KNN   0.021355  0.805361  0.020219  0.800000  0.039441  0.802694
# 9      LODA   0.043754  0.994672  0.000000  0.000000  0.000000  0.499833
# 10      LOF   0.035569  0.494339  0.003632  0.366667  0.007192  0.430823
# 11      MCD   0.005877  0.835997  0.026759  0.900000  0.051973  0.867838
# 12    OCSVM  13.529317  0.776557  0.019062  0.866667  0.037303  0.821386
# 13      PCA   0.003340  0.419414  0.000866  0.100000  0.001718  0.260509
# 14      ROD   2.981492  0.561605  0.001150  0.100000  0.002274  0.331961
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.3       14014      [amt]     0.426431
# 1         False   pyod         0.3       14014      [amt]     0.426431
# 2         False   pyod         0.3       14014      [amt]     0.426431
# 3         False   pyod         0.3       14014      [amt]     0.426431
# 4         False   pyod         0.3       14014      [amt]     0.426431
# 5         False   pyod         0.3       14014      [amt]     0.426431
# 6         False   pyod         0.3       14014      [amt]     0.426431
# 7         False   pyod         0.3       14014      [amt]     0.426431
# 8         False   pyod         0.3       14014      [amt]     0.426431
# 9         False   pyod         0.3       14014      [amt]     0.426431
# 10        False   pyod         0.3       14014      [amt]     0.426431
# 11        False   pyod         0.3       14014      [amt]     0.426431
# 12        False   pyod         0.3       14014      [amt]     0.426431
# 13        False   pyod         0.3       14014      [amt]     0.426431
# 14        False   pyod         0.3       14014      [amt]     0.426431
#
#     test_size  test_frate hyper_params
# 0        6006    0.004995         None
# 1        6006    0.004995         None
# 2        6006    0.004995         None
# 3        6006    0.004995         None
# 4        6006    0.004995         None
# 5        6006    0.004995         None
# 6        6006    0.004995         None
# 7        6006    0.004995         None
# 8        6006    0.004995         None
# 9        6006    0.004995         None
# 10       6006    0.004995         None
# 11       6006    0.004995         None
# 12       6006    0.004995         None
# 13       6006    0.004995         None
# 14       6006    0.004995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.005))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.870837  0.995005  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.006610  0.837829  0.024194  0.800000  0.046967  0.819009
# 2      ECOD   0.006332  0.805639  0.016988  0.666667  0.033131  0.736502
# 3       GMM   0.032188  0.804973  0.013636  0.533333  0.026593  0.669835
# 4      HBOS   0.002615  0.994672  0.000000  0.000000  0.000000  0.499833
# 5   IForest   0.685029  0.908092  0.042105  0.800000  0.080000  0.854317
# 6      INNE   0.737384  0.876124  0.026525  0.666667  0.051020  0.771921
# 7       KDE  13.335173  0.903985  0.040359  0.800000  0.076841  0.852253
# 8       KNN   0.029903  0.893884  0.033777  0.733333  0.064579  0.814012
# 9      LODA   0.062841  0.994672  0.000000  0.000000  0.000000  0.499833
# 10      LOF   0.049342  0.660340  0.004926  0.333333  0.009709  0.497657
# 11      MCD   0.006983  0.908314  0.042204  0.800000  0.080178  0.854429
# 12    OCSVM  28.749926  0.902875  0.039911  0.800000  0.076030  0.851696
# 13      PCA   0.005954  0.669331  0.002037  0.133333  0.004012  0.402677
# 14      ROD   6.543792  0.744145  0.000442  0.022222  0.000867  0.384996
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod         0.2       21021      [amt]     0.283574
# 1         False   pyod         0.2       21021      [amt]     0.283574
# 2         False   pyod         0.2       21021      [amt]     0.283574
# 3         False   pyod         0.2       21021      [amt]     0.283574
# 4         False   pyod         0.2       21021      [amt]     0.283574
# 5         False   pyod         0.2       21021      [amt]     0.283574
# 6         False   pyod         0.2       21021      [amt]     0.283574
# 7         False   pyod         0.2       21021      [amt]     0.283574
# 8         False   pyod         0.2       21021      [amt]     0.283574
# 9         False   pyod         0.2       21021      [amt]     0.283574
# 10        False   pyod         0.2       21021      [amt]     0.283574
# 11        False   pyod         0.2       21021      [amt]     0.283574
# 12        False   pyod         0.2       21021      [amt]     0.283574
# 13        False   pyod         0.2       21021      [amt]     0.283574
# 14        False   pyod         0.2       21021      [amt]     0.283574
#
#     test_size  test_frate hyper_params
# 0        9009    0.004995         None
# 1        9009    0.004995         None
# 2        9009    0.004995         None
# 3        9009    0.004995         None
# 4        9009    0.004995         None
# 5        9009    0.004995         None
# 6        9009    0.004995         None
# 7        9009    0.004995         None
# 8        9009    0.004995         None
# 9        9009    0.004995         None
# 10       9009    0.004995         None
# 11       9009    0.004995         None
# 12       9009    0.004995         None
# 13       9009    0.004995         None
# 14       9009    0.004995         None

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.09, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.08, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.07, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.06, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.05, 0.005))

# %% [markdown]
# # 안됨

# %%
```python
pyod(*pyod_preprocess4(fraudTrain, 0.005))
```
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pyod(*pyod_preprocess4(fraudTrain, 0.005))
#
# File ~/Dropbox/GNNpaper/posts/functions_pyod2.py:330, in pyod_preprocess4(fraudTrain, fraudrate)
#     328 def pyod_preprocess4(fraudTrain,fraudrate):
# --> 330     df = throw(fraudTrain,fraudrate)
#     331     df_tr, df_tstn = sklearn.model_selection.train_test_split(df)
#     335     X = pd.DataFrame(df_tr['amt'])
#
# File ~/Dropbox/GNNpaper/posts/functions_pyod2.py:12, in throw(df, fraud_rate, random_state)
#      10 df0 = df[df['is_fraud'] == 0].copy()
#      11 df0_downsample = (len(df1) * (1-fraud_rate)) / (len(df0) * fraud_rate)
# ---> 12 df0_down = df0.sample(frac=df0_downsample, random_state=random_state)
#      13 df_p = pd.concat([df1, df0_down])
#      14 return df_p
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:5765, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5762 # Process random_state argument
#    5763 rs = com.random_state(random_state)
# -> 5765 size = sample.process_sampling_size(n, frac, replace)
#    5766 if size is None:
#    5767     assert frac is not None
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/sample.py:103, in process_sampling_size(n, frac, replace)
#     101 assert frac is not None  # for mypy
#     102 if frac > 1 and not replace:
# --> 103     raise ValueError(
#     104         "Replace has to be set to `True` when "
#     105         "upsampling the population `frac` > 1."
#     106     )
#     107 if frac < 0:
#     108     raise ValueError(
#     109         "A negative number of rows requested. Please provide `frac` >= 0."
#     110     )
#
# ValueError: Replace has to be set to `True` when upsampling the population `frac` > 1.

# %% [markdown]
# # contamination must be in (0, 0.5], got: 0.5~ 오류로 아래 것들 안 됨

# %% [markdown]
# ```python
# pyod(*pyod_preprocess3(fraudTrain, 8))
#
# pyod(*pyod_preprocess3(fraudTrain, 7))
#
# pyod(*pyod_preprocess3(fraudTrain, 6))
#
# pyod(*pyod_preprocess3(fraudTrain, 3))
#
# pyod(*pyod_preprocess3(fraudTrain, 1))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.5))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.05))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.0005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.7, 0.005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.6, 0.005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.4, 0.005))
# ```
