# %% [raw]
# ---
# title: "[Pyod] 실험계속돌리기"
# author: "김보람 "
# date: "04/09/2024"
# ---

# %% [markdown]
# 1. 4/9
#
# 2. 4/9 v2
#
# 3. 4/10 v3
#
# 4. 4/10 v4
#
# 5. 4/10 v5
#
# 6. 4/11 v6

# %% [markdown]
# ref: <https://pyod.readthedocs.io/en/latest/pyod.models.html#all-models>
#
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions_pyod2.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %% [markdown]
# # pyod_preprocess4(비율 다 같게)

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.05))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.204882  0.942125  0.428475  0.418361  0.423358  0.694253
# 1       GMM  0.054761  0.963503  0.638120  0.649836  0.643925  0.815060
# 2      HBOS  0.931065  0.948685  0.404762  0.022295  0.042262  0.510271
# 3   IForest  1.909042  0.962937  0.633075  0.642623  0.637813  0.811348
# 4      INNE  2.101043  0.961572  0.621005  0.624262  0.622629  0.801940
# 5       KNN  0.107703  0.958109  0.586074  0.596066  0.591027  0.786772
# 6      LODA  0.144081  0.948685  0.404762  0.022295  0.042262  0.510271
# 7       LOF  0.189280  0.898468  0.029630  0.031475  0.030525  0.488164
# 8       MCD  0.018206  0.963503  0.638120  0.649836  0.643925  0.815060
# 9       PCA  0.006639  0.948452  0.492214  0.476721  0.484344  0.725205
# 10      ROD  5.989980  0.902131  0.002113  0.001967  0.002037  0.476128
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.05       90090      [amt]     0.049739
# 1         False   pyod        0.05       90090      [amt]     0.049739
# 2         False   pyod        0.05       90090      [amt]     0.049739
# 3         False   pyod        0.05       90090      [amt]     0.049739
# 4         False   pyod        0.05       90090      [amt]     0.049739
# 5         False   pyod        0.05       90090      [amt]     0.049739
# 6         False   pyod        0.05       90090      [amt]     0.049739
# 7         False   pyod        0.05       90090      [amt]     0.049739
# 8         False   pyod        0.05       90090      [amt]     0.049739
# 9         False   pyod        0.05       90090      [amt]     0.049739
# 10        False   pyod        0.05       90090      [amt]     0.049739
#
#     test_size  test_frate hyper_params
# 0       30030    0.050783         None
# 1       30030    0.050783         None
# 2       30030    0.050783         None
# 3       30030    0.050783         None
# 4       30030    0.050783         None
# 5       30030    0.050783         None
# 6       30030    0.050783         None
# 7       30030    0.050783         None
# 8       30030    0.050783         None
# 9       30030    0.050783         None
# 10      30030    0.050783         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.04))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.023269  0.953674  0.419016  0.428284  0.423600  0.701852
# 1       GMM  0.022120  0.966168  0.571154  0.597185  0.583879  0.789313
# 2      HBOS  0.006099  0.959854  0.000000  0.000000  0.000000  0.499792
# 3   IForest  2.415413  0.966114  0.570423  0.597185  0.583497  0.789285
# 4      INNE  2.636814  0.963717  0.542373  0.557641  0.549901  0.769083
# 5       KNN  0.144351  0.964303  0.549096  0.569705  0.559211  0.775170
# 6      LODA  0.179412  0.959854  0.000000  0.000000  0.000000  0.499792
# 7       LOF  0.245546  0.913714  0.018733  0.022788  0.020562  0.486690
# 8       MCD  0.021531  0.966168  0.571154  0.597185  0.583879  0.789313
# 9       PCA  0.007801  0.957270  0.463918  0.482574  0.473062  0.729746
# 10      ROD  4.862152  0.919415  0.001301  0.001340  0.001321  0.479378
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.04      112612      [amt]     0.040085
# 1         False   pyod        0.04      112612      [amt]     0.040085
# 2         False   pyod        0.04      112612      [amt]     0.040085
# 3         False   pyod        0.04      112612      [amt]     0.040085
# 4         False   pyod        0.04      112612      [amt]     0.040085
# 5         False   pyod        0.04      112612      [amt]     0.040085
# 6         False   pyod        0.04      112612      [amt]     0.040085
# 7         False   pyod        0.04      112612      [amt]     0.040085
# 8         False   pyod        0.04      112612      [amt]     0.040085
# 9         False   pyod        0.04      112612      [amt]     0.040085
# 10        False   pyod        0.04      112612      [amt]     0.040085
#
#     test_size  test_frate hyper_params
# 0       37538    0.039746         None
# 1       37538    0.039746         None
# 2       37538    0.039746         None
# 3       37538    0.039746         None
# 4       37538    0.039746         None
# 5       37538    0.039746         None
# 6       37538    0.039746         None
# 7       37538    0.039746         None
# 8       37538    0.039746         None
# 9       37538    0.039746         None
# 10      37538    0.039746         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.03))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.030927  0.961678  0.373486  0.385273  0.379288  0.682508
# 1       GMM  0.036566  0.969750  0.502248  0.514135  0.508122  0.749083
# 2      HBOS  0.007782  0.968511  0.000000  0.000000  0.000000  0.499433
# 3   IForest  3.344687  0.969750  0.502248  0.514135  0.508122  0.749083
# 4      INNE  3.769403  0.970390  0.512350  0.531887  0.521935  0.758010
# 5       KNN  0.187911  0.970170  0.509259  0.506246  0.507748  0.745478
# 6      LODA  0.351492  0.968511  0.000000  0.000000  0.000000  0.499433
# 7       LOF  0.348504  0.936503  0.038440  0.045365  0.041616  0.504899
# 8       MCD  0.030002  0.969750  0.502248  0.514135  0.508122  0.749083
# 9       PCA  0.012112  0.967972  0.474051  0.492439  0.483070  0.737658
# 10      ROD  6.480465  0.939640  0.000000  0.000000  0.000000  0.484545
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.03      150150      [amt]      0.02987
# 1         False   pyod        0.03      150150      [amt]      0.02987
# 2         False   pyod        0.03      150150      [amt]      0.02987
# 3         False   pyod        0.03      150150      [amt]      0.02987
# 4         False   pyod        0.03      150150      [amt]      0.02987
# 5         False   pyod        0.03      150150      [amt]      0.02987
# 6         False   pyod        0.03      150150      [amt]      0.02987
# 7         False   pyod        0.03      150150      [amt]      0.02987
# 8         False   pyod        0.03      150150      [amt]      0.02987
# 9         False   pyod        0.03      150150      [amt]      0.02987
# 10        False   pyod        0.03      150150      [amt]      0.02987
#
#     test_size  test_frate hyper_params
# 0       50050     0.03039         None
# 1       50050     0.03039         None
# 2       50050     0.03039         None
# 3       50050     0.03039         None
# 4       50050     0.03039         None
# 5       50050     0.03039         None
# 6       50050     0.03039         None
# 7       50050     0.03039         None
# 8       50050     0.03039         None
# 9       50050     0.03039         None
# 10      50050     0.03039         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.02))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ECOD  0.045344  0.972761  0.315210  0.330393  0.322623  0.658009
# 1       GMM  0.047855  0.978528  0.456439  0.490502  0.472858  0.739402
# 2      HBOS  0.010618  0.978635  0.060811  0.006106  0.011097  0.502109
# 3   IForest  5.052268  0.978795  0.462131  0.488467  0.474934  0.738541
# 4      INNE  5.432793  0.970283  0.252128  0.261194  0.256581  0.622839
# 5       KNN  0.318284  0.977303  0.425130  0.443012  0.433887  0.715508
# 6      LODA  0.503034  0.978635  0.060811  0.006106  0.011097  0.502109
# 7       LOF  0.556311  0.959654  0.008223  0.008820  0.008511  0.493758
# 8       MCD  0.046391  0.978528  0.456439  0.490502  0.472858  0.739402
# 9       PCA  0.016909  0.978208  0.449184  0.485753  0.466754  0.736912
# 10      ROD  9.129058  0.957816  0.001179  0.001357  0.001261  0.489164
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.02      225225      [amt]     0.020122
# 1         False   pyod        0.02      225225      [amt]     0.020122
# 2         False   pyod        0.02      225225      [amt]     0.020122
# 3         False   pyod        0.02      225225      [amt]     0.020122
# 4         False   pyod        0.02      225225      [amt]     0.020122
# 5         False   pyod        0.02      225225      [amt]     0.020122
# 6         False   pyod        0.02      225225      [amt]     0.020122
# 7         False   pyod        0.02      225225      [amt]     0.020122
# 8         False   pyod        0.02      225225      [amt]     0.020122
# 9         False   pyod        0.02      225225      [amt]     0.020122
# 10        False   pyod        0.02      225225      [amt]     0.020122
#
#     test_size  test_frate hyper_params
# 0       75075    0.019634         None
# 1       75075    0.019634         None
# 2       75075    0.019634         None
# 3       75075    0.019634         None
# 4       75075    0.019634         None
# 5       75075    0.019634         None
# 6       75075    0.019634         None
# 7       75075    0.019634         None
# 8       75075    0.019634         None
# 9       75075    0.019634         None
# 10      75075    0.019634         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.01))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.088912  0.984163  0.228702  0.225161  0.226918  0.608620
# 1       GMM   0.137685  0.989244  0.478232  0.460645  0.469274  0.727701
# 2      HBOS   0.020032  0.989257  0.000000  0.000000  0.000000  0.499788
# 3   IForest  10.011184  0.989231  0.477502  0.458710  0.467917  0.726737
# 4      INNE  12.012180  0.989384  0.484993  0.458710  0.471485  0.726814
# 5       KNN   0.710377  0.987473  0.390179  0.379355  0.384691  0.686585
# 6      LODA   1.028260  0.989257  0.000000  0.000000  0.000000  0.499788
# 7       LOF   1.147206  0.979920  0.000682  0.000645  0.000663  0.495390
# 8       MCD   0.079864  0.989244  0.478232  0.460645  0.469274  0.727701
# 9       PCA   0.026193  0.989244  0.478232  0.460645  0.469274  0.727701
# 10      ROD  15.265756  0.974759  0.000000  0.000000  0.000000  0.492463
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.01      450450      [amt]     0.009892
# 1         False   pyod        0.01      450450      [amt]     0.009892
# 2         False   pyod        0.01      450450      [amt]     0.009892
# 3         False   pyod        0.01      450450      [amt]     0.009892
# 4         False   pyod        0.01      450450      [amt]     0.009892
# 5         False   pyod        0.01      450450      [amt]     0.009892
# 6         False   pyod        0.01      450450      [amt]     0.009892
# 7         False   pyod        0.01      450450      [amt]     0.009892
# 8         False   pyod        0.01      450450      [amt]     0.009892
# 9         False   pyod        0.01      450450      [amt]     0.009892
# 10        False   pyod        0.01      450450      [amt]     0.009892
#
#     test_size  test_frate hyper_params
# 0      150150    0.010323         None
# 1      150150    0.010323         None
# 2      150150    0.010323         None
# 3      150150    0.010323         None
# 4      150150    0.010323         None
# 5      150150    0.010323         None
# 6      150150    0.010323         None
# 7      150150    0.010323         None
# 8      150150    0.010323         None
# 9      150150    0.010323         None
# 10     150150    0.010323         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.00573))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.182414  0.989685  0.123262  0.129054  0.126091  0.561865
# 1       GMM   0.143922  0.992730  0.374522  0.389146  0.381694  0.692689
# 2      HBOS   0.031416  0.993890  0.000000  0.000000  0.000000  0.499827
# 3   IForest  21.304815  0.992791  0.377432  0.385175  0.381264  0.690745
# 4      INNE  25.399340  0.992856  0.378451  0.371939  0.375167  0.684198
# 5       KNN   1.525798  0.991826  0.300190  0.313700  0.306796  0.654729
# 6      LODA   1.546738  0.993890  0.000000  0.000000  0.000000  0.499827
# 7       LOF   2.222327  0.988574  0.000000  0.000000  0.000000  0.497154
# 8       MCD   0.143405  0.992730  0.374522  0.389146  0.381694  0.692689
# 9       PCA   0.058429  0.992730  0.374522  0.389146  0.381694  0.692689
# 10      ROD  18.767850  0.989273  0.000000  0.000000  0.000000  0.497505
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod     0.00573      786126      [amt]     0.005718
# 1         False   pyod     0.00573      786126      [amt]     0.005718
# 2         False   pyod     0.00573      786126      [amt]     0.005718
# 3         False   pyod     0.00573      786126      [amt]     0.005718
# 4         False   pyod     0.00573      786126      [amt]     0.005718
# 5         False   pyod     0.00573      786126      [amt]     0.005718
# 6         False   pyod     0.00573      786126      [amt]     0.005718
# 7         False   pyod     0.00573      786126      [amt]     0.005718
# 8         False   pyod     0.00573      786126      [amt]     0.005718
# 9         False   pyod     0.00573      786126      [amt]     0.005718
# 10        False   pyod     0.00573      786126      [amt]     0.005718
#
#     test_size  test_frate hyper_params
# 0      262042    0.005766         None
# 1      262042    0.005766         None
# 2      262042    0.005766         None
# 3      262042    0.005766         None
# 4      262042    0.005766         None
# 5      262042    0.005766         None
# 6      262042    0.005766         None
# 7      262042    0.005766         None
# 8      262042    0.005766         None
# 9      262042    0.005766         None
# 10     262042    0.005766         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.006))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.173190  0.989746  0.135029  0.143055  0.138926  0.568863
# 1       GMM   0.166684  0.992863  0.387075  0.401520  0.394166  0.698911
# 2      HBOS   0.024031  0.993914  0.000000  0.000000  0.000000  0.499847
# 3   IForest  18.418076  0.992883  0.386549  0.393227  0.389860  0.694799
# 4      INNE  21.839734  0.991944  0.297509  0.288874  0.293128  0.642453
# 5       KNN   1.415705  0.991940  0.306122  0.310988  0.308536  0.653444
# 6      LODA   1.726294  0.993914  0.000000  0.000000  0.000000  0.499847
# 7       LOF   2.098400  0.989039  0.001538  0.001382  0.001456  0.498083
# 8       MCD   0.145731  0.992863  0.387075  0.401520  0.394166  0.698911
# 9       PCA   0.047649  0.992863  0.387075  0.401520  0.394166  0.698911
# 10      ROD  12.118081  0.992723  0.000000  0.000000  0.000000  0.499248
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.006      750750      [amt]     0.006073
# 1         False   pyod       0.006      750750      [amt]     0.006073
# 2         False   pyod       0.006      750750      [amt]     0.006073
# 3         False   pyod       0.006      750750      [amt]     0.006073
# 4         False   pyod       0.006      750750      [amt]     0.006073
# 5         False   pyod       0.006      750750      [amt]     0.006073
# 6         False   pyod       0.006      750750      [amt]     0.006073
# 7         False   pyod       0.006      750750      [amt]     0.006073
# 8         False   pyod       0.006      750750      [amt]     0.006073
# 9         False   pyod       0.006      750750      [amt]     0.006073
# 10        False   pyod       0.006      750750      [amt]     0.006073
#
#     test_size  test_frate hyper_params
# 0      250250    0.005782         None
# 1      250250    0.005782         None
# 2      250250    0.005782         None
# 3      250250    0.005782         None
# 4      250250    0.005782         None
# 5      250250    0.005782         None
# 6      250250    0.005782         None
# 7      250250    0.005782         None
# 8      250250    0.005782         None
# 9      250250    0.005782         None
# 10     250250    0.005782         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.007))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.135192  0.988415  0.178926  0.178100  0.178512  0.586141
# 1       GMM   0.249722  0.992084  0.438263  0.426121  0.432107  0.711117
# 2      HBOS   0.028765  0.992615  0.000000  0.000000  0.000000  0.499840
# 3   IForest  19.286734  0.992061  0.435115  0.413588  0.424078  0.704883
# 4      INNE  18.123929  0.991618  0.398707  0.366095  0.381706  0.681083
# 5       KNN   1.141550  0.990825  0.344780  0.331135  0.337820  0.663328
# 6      LODA   1.468757  0.992615  0.000000  0.000000  0.000000  0.499840
# 7       LOF   1.683333  0.986075  0.001356  0.001319  0.001337  0.497202
# 8       MCD   0.128608  0.992084  0.438263  0.426121  0.432107  0.711117
# 9       PCA   0.040648  0.992084  0.438263  0.426121  0.432107  0.711117
# 10      ROD  11.569438  0.980182  0.000000  0.000000  0.000000  0.493579
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.007      643500      [amt]     0.006977
# 1         False   pyod       0.007      643500      [amt]     0.006977
# 2         False   pyod       0.007      643500      [amt]     0.006977
# 3         False   pyod       0.007      643500      [amt]     0.006977
# 4         False   pyod       0.007      643500      [amt]     0.006977
# 5         False   pyod       0.007      643500      [amt]     0.006977
# 6         False   pyod       0.007      643500      [amt]     0.006977
# 7         False   pyod       0.007      643500      [amt]     0.006977
# 8         False   pyod       0.007      643500      [amt]     0.006977
# 9         False   pyod       0.007      643500      [amt]     0.006977
# 10        False   pyod       0.007      643500      [amt]     0.006977
#
#     test_size  test_frate hyper_params
# 0      214500    0.007068         None
# 1      214500    0.007068         None
# 2      214500    0.007068         None
# 3      214500    0.007068         None
# 4      214500    0.007068         None
# 5      214500    0.007068         None
# 6      214500    0.007068         None
# 7      214500    0.007068         None
# 8      214500    0.007068         None
# 9      214500    0.007068         None
# 10     214500    0.007068         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.008))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.129930  0.987000  0.194848  0.194591  0.194719  0.594022
# 1       GMM   0.121972  0.991326  0.460784  0.434037  0.447011  0.714950
# 2      HBOS   0.025059  0.991624  0.000000  0.000000  0.000000  0.499850
# 3   IForest  14.189543  0.991347  0.461972  0.432718  0.446866  0.714307
# 4      INNE  14.836553  0.990815  0.425287  0.390501  0.407153  0.693102
# 5       KNN   0.906332  0.990005  0.371060  0.341689  0.355769  0.668486
# 6      LODA   1.305442  0.991624  0.000000  0.000000  0.000000  0.499850
# 7       LOF   1.555316  0.984863  0.000754  0.000660  0.000703  0.496769
# 8       MCD   0.107831  0.991326  0.460784  0.434037  0.447011  0.714950
# 9       PCA   0.040088  0.991326  0.460784  0.434037  0.447011  0.714950
# 10      ROD  12.531487  0.984304  0.000000  0.000000  0.000000  0.496159
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.008      563062      [amt]     0.007974
# 1         False   pyod       0.008      563062      [amt]     0.007974
# 2         False   pyod       0.008      563062      [amt]     0.007974
# 3         False   pyod       0.008      563062      [amt]     0.007974
# 4         False   pyod       0.008      563062      [amt]     0.007974
# 5         False   pyod       0.008      563062      [amt]     0.007974
# 6         False   pyod       0.008      563062      [amt]     0.007974
# 7         False   pyod       0.008      563062      [amt]     0.007974
# 8         False   pyod       0.008      563062      [amt]     0.007974
# 9         False   pyod       0.008      563062      [amt]     0.007974
# 10        False   pyod       0.008      563062      [amt]     0.007974
#
#     test_size  test_frate hyper_params
# 0      187688    0.008077         None
# 1      187688    0.008077         None
# 2      187688    0.008077         None
# 3      187688    0.008077         None
# 4      187688    0.008077         None
# 5      187688    0.008077         None
# 6      187688    0.008077         None
# 7      187688    0.008077         None
# 8      187688    0.008077         None
# 9      187688    0.008077         None
# 10     187688    0.008077         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.009))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.098087  0.985674  0.218110  0.214704  0.216393  0.603774
# 1       GMM   0.112110  0.990386  0.477592  0.464541  0.470976  0.729908
# 2      HBOS   0.022598  0.990452  0.000000  0.000000  0.000000  0.499831
# 3   IForest  14.228854  0.990506  0.483871  0.458686  0.470942  0.727068
# 4      INNE  13.061974  0.988270  0.353147  0.328562  0.340411  0.661483
# 5       KNN   0.812692  0.988899  0.391753  0.370852  0.381016  0.682749
# 6      LODA   1.128273  0.990452  0.000000  0.000000  0.000000  0.499831
# 7       LOF   1.293245  0.981233  0.001875  0.001952  0.001913  0.496145
# 8       MCD   0.098309  0.990386  0.477592  0.464541  0.470976  0.729908
# 9       PCA   0.039383  0.990386  0.477592  0.464541  0.470976  0.729908
# 10      ROD  11.899739  0.985063  0.000000  0.000000  0.000000  0.497111
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.009      500499      [amt]     0.008929
# 1         False   pyod       0.009      500499      [amt]     0.008929
# 2         False   pyod       0.009      500499      [amt]     0.008929
# 3         False   pyod       0.009      500499      [amt]     0.008929
# 4         False   pyod       0.009      500499      [amt]     0.008929
# 5         False   pyod       0.009      500499      [amt]     0.008929
# 6         False   pyod       0.009      500499      [amt]     0.008929
# 7         False   pyod       0.009      500499      [amt]     0.008929
# 8         False   pyod       0.009      500499      [amt]     0.008929
# 9         False   pyod       0.009      500499      [amt]     0.008929
# 10        False   pyod       0.009      500499      [amt]     0.008929
#
#     test_size  test_frate hyper_params
# 0      166834    0.009213         None
# 1      166834    0.009213         None
# 2      166834    0.009213         None
# 3      166834    0.009213         None
# 4      166834    0.009213         None
# 5      166834    0.009213         None
# 6      166834    0.009213         None
# 7      166834    0.009213         None
# 8      166834    0.009213         None
# 9      166834    0.009213         None
# 10     166834    0.009213         None

# %% [markdown]
# # pyod_preprocess7

# %%
def pyod_preprocess7(fraudTrain, ratio, n):
    
    df50 = throw(fraudTrain,ratio)
    df_tr, a= sklearn.model_selection.train_test_split(df50)
        
    dfn = fraudTrain[::n]
    dfnn = dfn[~dfn.index.isin(df_tr.index)]
    dfnn = dfnn.reset_index(drop=True)
    b, df_tst = sklearn.model_selection.train_test_split(dfnn)   
    df2, mask = concat(df_tr, df_tst)
    df2['index'] = df2.index
    df = df2.reset_index()
    
    
    X = pd.DataFrame(df_tr['amt'])
    y = pd.DataFrame(df_tr['is_fraud'])
    XX = pd.DataFrame(df_tst['amt'])
    yy = pd.DataFrame(df_tst['is_fraud'])
    fraud_ratio = df.is_fraud.mean()
    predictors = {
    'ABOD': ABOD(contamination=fraud_ratio),
#    'ALAD': ALAD(contamination=fraud_ratio),
#    'AnoGAN': AnoGAN(contamination=fraud_ratio),
#    'AutoEncoder':AutoEncoder(contamination=fraud_ratio),
##    'CBLOF': CBLOF(contamination=fraud_ratio,n_clusters=2),
##    'COF': COF(contamination=fraud_ratio),
##    'CD': CD(contamination=fraud_ratio),
    'COPOD': COPOD(contamination=fraud_ratio),
#    'DeepSVDD': DeepSVDD(contamination=fraud_ratio),
#    'DIF': DIF(contamination=fraud_ratio),    
    'ECOD': ECOD(contamination=fraud_ratio),
#    'FeatureBagging': FeatureBagging(contamination=fraud_ratio),
    'GMM': GMM(contamination=fraud_ratio),
    'HBOS': HBOS(contamination=fraud_ratio),
    'IForest': IForest(contamination=fraud_ratio),
    'INNE': INNE(contamination=fraud_ratio),
    'KDE': KDE(contamination=fraud_ratio),
    'KNN': KNN(contamination=fraud_ratio),
####    'KPCA': KPCA(contamination=fraud_ratio),
#    'PyODKernelPCA': PyODKernelPCA(contamination=fraud_ratio),
##    'LMDD': LMDD(contamination=fraud_ratio),
    'LODA': LODA(contamination=fraud_ratio),
    'LOF': LOF(contamination=fraud_ratio),
####    'LOCI': LOCI(contamination=fraud_ratio),
#    'LUNAR': LUNAR(contamination=fraud_ratio),
    'LODA': LODA(contamination=fraud_ratio),
#    'LSCP': LSCP(contamination=fraud_ratio),
#    'MAD': MAD(contamination=fraud_ratio),
    'MCD': MCD(contamination=fraud_ratio),
#    'MO_GAAL': MO_GAAL(contamination=fraud_ratio),
    'OCSVM': OCSVM(contamination=fraud_ratio),
    'PCA': PCA(contamination=fraud_ratio),
###    'QMCD': QMCD(contamination=fraud_ratio),
####    'RGraph': RGraph(contamination=fraud_ratio),
    'ROD': ROD(contamination=fraud_ratio),
##    'Sampling': Sampling(contamination=fraud_ratio),
##   'SOD': SOD(contamination=fraud_ratio),
#    'SO_GAAL': SO_GAAL(contamination=fraud_ratio),
####    'SOS': SOS(contamination=fraud_ratio),
#    'SUOD': SUOD(contamination=fraud_ratio),
#    'VAE': VAE(contamination=fraud_ratio),
#    'XGBOD': XGBOD(contamination=fraud_ratio),  
}
    return X, XX, y, yy, predictors, fraud_ratio

# %%
def pyod(X,XX,y,yy,predictors,throw_rate):
    model = []
    time_diff = []
    acc = []
    pre = []
    rec = []
    f1 = [] 
    auc = [] 
    graph_based = []
    method = [] 
    train_size = []
    train_cols = []
    train_frate = []
    test_size = []
    test_frate = []
    hyper_params = [] 
    for name, predictor in predictors.items():
        t1 = time.time()
        predictor.fit(X,y)
        t2 = time.time()
        yyhat = predictor.predict(XX)
        scores = evaluate(yy,yyhat)
        model.append(name)
        time_diff.append(t2-t1)
        acc.append(scores['acc'])
        pre.append(scores['pre'])
        rec.append(scores['rec'])
        f1.append(scores['f1'])
        auc.append(scores['auc'])
        graph_based.append(False)
        method.append('pyod')
        train_size.append(len(y)),
        train_cols.append(list(X.columns)),
        train_frate.append(np.array(y).reshape(-1).mean()),
        test_size.append(len(yy)),
        test_frate.append(np.array(yy).reshape(-1).mean())
        hyper_params.append(None)
    df_results = pd.DataFrame(dict(
        model = model,
        time=time_diff,
        acc=acc,
        pre=pre,
        rec=rec,
        f1=f1,
        auc=auc,
        graph_based = graph_based,
        method = method,
        throw_rate = throw_rate,
        train_size = train_size,
        train_cols = train_cols,
        train_frate = train_frate,
        test_size = test_size,
        test_frate = test_frate,
        hyper_params = hyper_params
    ))
    ymdhms = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d-%H%M%S') 
    df_results.to_csv(f'../results/{ymdhms}-pyod.csv',index=False)
    return df_results

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.1,10))
# Out:
#       model        time       acc       pre       rec        f1       auc  \
# 0      ABOD    2.661346  0.998206  0.000000  0.000000  0.000000  0.500000
# 1     COPOD    0.010578  0.976360  0.043333  0.577778  0.080620  0.777427
# 2      ECOD    0.010265  0.960494  0.016360  0.355556  0.031281  0.658569
# 3       GMM    0.022787  0.983536  0.053398  0.488889  0.096280  0.736657
# 4      HBOS    0.003571  0.998087  0.000000  0.000000  0.000000  0.499940
# 5   IForest    1.141731  0.983576  0.053528  0.488889  0.096491  0.736677
# 6      INNE    1.100540  0.983137  0.047847  0.444444  0.086393  0.714275
# 7       KDE   55.831534  0.982181  0.049327  0.488889  0.089613  0.735978
# 8       KNN    0.053818  0.980068  0.042254  0.466667  0.077491  0.723829
# 9      LODA    0.094716  0.998087  0.000000  0.000000  0.000000  0.499940
# 10      LOF    0.092285  0.920789  0.002561  0.111111  0.005008  0.516678
# 11      MCD    0.011377  0.983536  0.053398  0.488889  0.096280  0.736657
# 12    OCSVM  135.107861  0.981702  0.048035  0.488889  0.087475  0.735738
# 13      PCA    0.004937  0.974965  0.026016  0.355556  0.048485  0.665817
# 14      ROD    4.764429  0.929878  0.000000  0.000000  0.000000  0.465775
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.065222       45045      [amt]     0.100544
# 1         False   pyod    0.065222       45045      [amt]     0.100544
# 2         False   pyod    0.065222       45045      [amt]     0.100544
# 3         False   pyod    0.065222       45045      [amt]     0.100544
# 4         False   pyod    0.065222       45045      [amt]     0.100544
# 5         False   pyod    0.065222       45045      [amt]     0.100544
# 6         False   pyod    0.065222       45045      [amt]     0.100544
# 7         False   pyod    0.065222       45045      [amt]     0.100544
# 8         False   pyod    0.065222       45045      [amt]     0.100544
# 9         False   pyod    0.065222       45045      [amt]     0.100544
# 10        False   pyod    0.065222       45045      [amt]     0.100544
# 11        False   pyod    0.065222       45045      [amt]     0.100544
# 12        False   pyod    0.065222       45045      [amt]     0.100544
# 13        False   pyod    0.065222       45045      [amt]     0.100544
# 14        False   pyod    0.065222       45045      [amt]     0.100544
#
#     test_size  test_frate hyper_params
# 0       25085    0.001794         None
# 1       25085    0.001794         None
# 2       25085    0.001794         None
# 3       25085    0.001794         None
# 4       25085    0.001794         None
# 5       25085    0.001794         None
# 6       25085    0.001794         None
# 7       25085    0.001794         None
# 8       25085    0.001794         None
# 9       25085    0.001794         None
# 10      25085    0.001794         None
# 11      25085    0.001794         None
# 12      25085    0.001794         None
# 13      25085    0.001794         None
# 14      25085    0.001794         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.2,10))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   1.267796  0.999064  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.006136  0.970749  0.022368  0.708333  0.043367  0.839664
# 2      ECOD   0.006248  0.943838  0.005587  0.333333  0.010989  0.638872
# 3       GMM   0.032860  0.994579  0.061069  0.333333  0.103226  0.664266
# 4      HBOS   0.002854  0.998713  0.000000  0.000000  0.000000  0.499824
# 5   IForest   0.683904  0.983346  0.016787  0.291667  0.031746  0.637831
# 6      INNE   0.580262  0.941888  0.004060  0.250000  0.007989  0.596268
# 7       KDE  12.958058  0.978471  0.016484  0.375000  0.031579  0.677018
# 8       KNN   0.025596  0.976716  0.011925  0.291667  0.022913  0.634512
# 9      LODA   0.061688  0.998713  0.000000  0.000000  0.000000  0.499824
# 10      LOF   0.055065  0.879407  0.000976  0.125000  0.001937  0.502557
# 11      MCD   0.007768  0.994579  0.061069  0.333333  0.103226  0.664266
# 12    OCSVM  30.700971  0.977535  0.014085  0.333333  0.027027  0.655736
# 13      PCA   0.003361  0.917668  0.000000  0.000000  0.000000  0.459264
# 14      ROD   2.901302  0.872387  0.000000  0.000000  0.000000  0.436602
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.094597       22522      [amt]     0.201225
# 1         False   pyod    0.094597       22522      [amt]     0.201225
# 2         False   pyod    0.094597       22522      [amt]     0.201225
# 3         False   pyod    0.094597       22522      [amt]     0.201225
# 4         False   pyod    0.094597       22522      [amt]     0.201225
# 5         False   pyod    0.094597       22522      [amt]     0.201225
# 6         False   pyod    0.094597       22522      [amt]     0.201225
# 7         False   pyod    0.094597       22522      [amt]     0.201225
# 8         False   pyod    0.094597       22522      [amt]     0.201225
# 9         False   pyod    0.094597       22522      [amt]     0.201225
# 10        False   pyod    0.094597       22522      [amt]     0.201225
# 11        False   pyod    0.094597       22522      [amt]     0.201225
# 12        False   pyod    0.094597       22522      [amt]     0.201225
# 13        False   pyod    0.094597       22522      [amt]     0.201225
# 14        False   pyod    0.094597       22522      [amt]     0.201225
#
#     test_size  test_frate hyper_params
# 0       25640    0.000936         None
# 1       25640    0.000936         None
# 2       25640    0.000936         None
# 3       25640    0.000936         None
# 4       25640    0.000936         None
# 5       25640    0.000936         None
# 6       25640    0.000936         None
# 7       25640    0.000936         None
# 8       25640    0.000936         None
# 9       25640    0.000936         None
# 10      25640    0.000936         None
# 11      25640    0.000936         None
# 12      25640    0.000936         None
# 13      25640    0.000936         None
# 14      25640    0.000936         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.3,10))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ABOD   0.991607  0.998258  0.000000  0.000000  0.000000  0.500000
# 1     COPOD   0.004611  0.965708  0.033296  0.666667  0.063425  0.816448
# 2      ECOD   0.004372  0.932345  0.011474  0.444444  0.022371  0.688820
# 3       GMM   0.019598  0.995201  0.156522  0.400000  0.225000  0.698120
# 4      HBOS   0.002411  0.997910  0.000000  0.000000  0.000000  0.499826
# 5   IForest   0.505826  0.984131  0.044888  0.400000  0.080717  0.692575
# 6      INNE   0.408714  0.934125  0.007139  0.266667  0.013905  0.600978
# 7       KDE   4.967871  0.970391  0.020000  0.333333  0.037736  0.652418
# 8       KNN   0.027596  0.971436  0.016736  0.266667  0.031496  0.619666
# 9      LODA   0.053558  0.997910  0.000000  0.000000  0.000000  0.499826
# 10      LOF   0.039742  0.860820  0.001124  0.088889  0.002220  0.475528
# 11      MCD   0.006628  0.995201  0.156522  0.400000  0.225000  0.698120
# 12    OCSVM  12.117140  0.968417  0.019925  0.355556  0.037736  0.662521
# 13      PCA   0.003074  0.848473  0.000000  0.000000  0.000000  0.424977
# 14      ROD   2.718539  0.998220  0.000000  0.000000  0.000000  0.499981
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.111378       15015      [amt]     0.300033
# 1         False   pyod    0.111378       15015      [amt]     0.300033
# 2         False   pyod    0.111378       15015      [amt]     0.300033
# 3         False   pyod    0.111378       15015      [amt]     0.300033
# 4         False   pyod    0.111378       15015      [amt]     0.300033
# 5         False   pyod    0.111378       15015      [amt]     0.300033
# 6         False   pyod    0.111378       15015      [amt]     0.300033
# 7         False   pyod    0.111378       15015      [amt]     0.300033
# 8         False   pyod    0.111378       15015      [amt]     0.300033
# 9         False   pyod    0.111378       15015      [amt]     0.300033
# 10        False   pyod    0.111378       15015      [amt]     0.300033
# 11        False   pyod    0.111378       15015      [amt]     0.300033
# 12        False   pyod    0.111378       15015      [amt]     0.300033
# 13        False   pyod    0.111378       15015      [amt]     0.300033
# 14        False   pyod    0.111378       15015      [amt]     0.300033
#
#     test_size  test_frate hyper_params
# 0       25837    0.001742         None
# 1       25837    0.001742         None
# 2       25837    0.001742         None
# 3       25837    0.001742         None
# 4       25837    0.001742         None
# 5       25837    0.001742         None
# 6       25837    0.001742         None
# 7       25837    0.001742         None
# 8       25837    0.001742         None
# 9       25837    0.001742         None
# 10      25837    0.001742         None
# 11      25837    0.001742         None
# 12      25837    0.001742         None
# 13      25837    0.001742         None
# 14      25837    0.001742         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.4,10))
# Out:
#       model      time       acc       pre       rec        f1       auc  \
# 0      ABOD  0.671650  0.998342  0.000000  0.000000  0.000000  0.500000
# 1     COPOD  0.004716  0.963360  0.030052  0.674419  0.057540  0.819129
# 2      ECOD  0.003848  0.925795  0.007334  0.325581  0.014344  0.626186
# 3       GMM  0.042788  0.995526  0.080460  0.162791  0.107692  0.579850
# 4      HBOS  0.002278  0.998149  0.000000  0.000000  0.000000  0.499903
# 5   IForest  0.474321  0.970032  0.014550  0.255814  0.027534  0.613516
# 6      INNE  0.432699  0.896868  0.001893  0.116279  0.003726  0.507222
# 7       KDE  3.191780  0.956032  0.011576  0.302326  0.022298  0.629722
# 8       KNN  0.012626  0.967371  0.013333  0.255814  0.025346  0.612184
# 9      LODA  0.033701  0.998149  0.000000  0.000000  0.000000  0.499903
# 10      LOF  0.026070  0.838977  0.002408  0.232558  0.004768  0.536271
# 11      MCD  0.005463  0.995526  0.080460  0.162791  0.107692  0.579850
# 12    OCSVM  6.369027  0.956958  0.011829  0.302326  0.022767  0.630185
# 13      PCA  0.002807  0.812288  0.000207  0.023256  0.000411  0.418427
# 14      ROD  1.383389  0.998342  0.000000  0.000000  0.000000  0.500000
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.121004       11261      [amt]     0.395791
# 1         False   pyod    0.121004       11261      [amt]     0.395791
# 2         False   pyod    0.121004       11261      [amt]     0.395791
# 3         False   pyod    0.121004       11261      [amt]     0.395791
# 4         False   pyod    0.121004       11261      [amt]     0.395791
# 5         False   pyod    0.121004       11261      [amt]     0.395791
# 6         False   pyod    0.121004       11261      [amt]     0.395791
# 7         False   pyod    0.121004       11261      [amt]     0.395791
# 8         False   pyod    0.121004       11261      [amt]     0.395791
# 9         False   pyod    0.121004       11261      [amt]     0.395791
# 10        False   pyod    0.121004       11261      [amt]     0.395791
# 11        False   pyod    0.121004       11261      [amt]     0.395791
# 12        False   pyod    0.121004       11261      [amt]     0.395791
# 13        False   pyod    0.121004       11261      [amt]     0.395791
# 14        False   pyod    0.121004       11261      [amt]     0.395791
#
#     test_size  test_frate hyper_params
# 0       25928    0.001658         None
# 1       25928    0.001658         None
# 2       25928    0.001658         None
# 3       25928    0.001658         None
# 4       25928    0.001658         None
# 5       25928    0.001658         None
# 6       25928    0.001658         None
# 7       25928    0.001658         None
# 8       25928    0.001658         None
# 9       25928    0.001658         None
# 10      25928    0.001658         None
# 11      25928    0.001658         None
# 12      25928    0.001658         None
# 13      25928    0.001658         None
# 14      25928    0.001658         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.5,10))
# Out:
#       model      time       acc       pre      rec        f1       auc  \
# 0      ABOD  0.548842  0.998768  0.000000  0.00000  0.000000  0.500000
# 1     COPOD  0.003445  0.960701  0.023144  0.75000  0.044902  0.855480
# 2      ECOD  0.003357  0.919861  0.005309  0.34375  0.010456  0.632161
# 3       GMM  0.032777  0.995881  0.078652  0.21875  0.115702  0.607795
# 4      HBOS  0.002157  0.998576  0.000000  0.00000  0.000000  0.499904
# 5   IForest  0.343207  0.939800  0.003243  0.15625  0.006353  0.548508
# 6      INNE  0.261438  0.886451  0.002048  0.18750  0.004051  0.537407
# 7       KDE  2.072245  0.938414  0.003797  0.18750  0.007444  0.563420
# 8       KNN  0.009778  0.953926  0.005098  0.18750  0.009926  0.571186
# 9      LODA  0.031229  0.998576  0.000000  0.00000  0.000000  0.499904
# 10      LOF  0.020731  0.850500  0.002068  0.25000  0.004103  0.550620
# 11      MCD  0.005078  0.995881  0.078652  0.21875  0.115702  0.607795
# 12    OCSVM  4.094836  0.939376  0.004496  0.21875  0.008811  0.579508
# 13      PCA  0.003615  0.782679  0.000178  0.03125  0.000354  0.407428
# 14      ROD  1.694649  0.998768  0.000000  0.00000  0.000000  0.500000
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.130127        9009      [amt]     0.501832
# 1         False   pyod    0.130127        9009      [amt]     0.501832
# 2         False   pyod    0.130127        9009      [amt]     0.501832
# 3         False   pyod    0.130127        9009      [amt]     0.501832
# 4         False   pyod    0.130127        9009      [amt]     0.501832
# 5         False   pyod    0.130127        9009      [amt]     0.501832
# 6         False   pyod    0.130127        9009      [amt]     0.501832
# 7         False   pyod    0.130127        9009      [amt]     0.501832
# 8         False   pyod    0.130127        9009      [amt]     0.501832
# 9         False   pyod    0.130127        9009      [amt]     0.501832
# 10        False   pyod    0.130127        9009      [amt]     0.501832
# 11        False   pyod    0.130127        9009      [amt]     0.501832
# 12        False   pyod    0.130127        9009      [amt]     0.501832
# 13        False   pyod    0.130127        9009      [amt]     0.501832
# 14        False   pyod    0.130127        9009      [amt]     0.501832
#
#     test_size  test_frate hyper_params
# 0       25980    0.001232         None
# 1       25980    0.001232         None
# 2       25980    0.001232         None
# 3       25980    0.001232         None
# 4       25980    0.001232         None
# 5       25980    0.001232         None
# 6       25980    0.001232         None
# 7       25980    0.001232         None
# 8       25980    0.001232         None
# 9       25980    0.001232         None
# 10      25980    0.001232         None
# 11      25980    0.001232         None
# 12      25980    0.001232         None
# 13      25980    0.001232         None
# 14      25980    0.001232         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.09,10))
# Out:
#       model        time       acc       pre       rec        f1       auc  \
# 0      ABOD    2.428764  0.998196  0.000000  0.000000  0.000000  0.500000
# 1     COPOD    0.011578  0.975709  0.037891  0.511111  0.070552  0.743830
# 2      ECOD    0.011518  0.961839  0.017039  0.355556  0.032520  0.659245
# 3       GMM    0.032487  0.981641  0.046154  0.466667  0.084000  0.724619
# 4      HBOS    0.003770  0.995470  0.085366  0.155556  0.110236  0.576272
# 5   IForest    1.213922  0.981681  0.046256  0.466667  0.084168  0.724639
# 6      INNE    1.219214  0.980920  0.040512  0.422222  0.073930  0.702076
# 7       KDE   72.447918  0.981240  0.045161  0.466667  0.082353  0.724418
# 8       KNN    0.070164  0.978755  0.041588  0.488889  0.076655  0.734265
# 9      LODA    0.091145  0.995470  0.085366  0.155556  0.110236  0.576272
# 10      LOF    0.122226  0.917946  0.001494  0.066667  0.002923  0.493076
# 11      MCD    0.015638  0.981641  0.046154  0.466667  0.084000  0.724619
# 12    OCSVM  168.239579  0.979958  0.044088  0.488889  0.080882  0.734867
# 13      PCA    0.005844  0.979076  0.031434  0.355556  0.057762  0.667879
# 14      ROD    7.566946  0.932296  0.000000  0.000000  0.000000  0.466991
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod     0.06115       50049      [amt]     0.090731
# 1         False   pyod     0.06115       50049      [amt]     0.090731
# 2         False   pyod     0.06115       50049      [amt]     0.090731
# 3         False   pyod     0.06115       50049      [amt]     0.090731
# 4         False   pyod     0.06115       50049      [amt]     0.090731
# 5         False   pyod     0.06115       50049      [amt]     0.090731
# 6         False   pyod     0.06115       50049      [amt]     0.090731
# 7         False   pyod     0.06115       50049      [amt]     0.090731
# 8         False   pyod     0.06115       50049      [amt]     0.090731
# 9         False   pyod     0.06115       50049      [amt]     0.090731
# 10        False   pyod     0.06115       50049      [amt]     0.090731
# 11        False   pyod     0.06115       50049      [amt]     0.090731
# 12        False   pyod     0.06115       50049      [amt]     0.090731
# 13        False   pyod     0.06115       50049      [amt]     0.090731
# 14        False   pyod     0.06115       50049      [amt]     0.090731
#
#     test_size  test_frate hyper_params
# 0       24947    0.001804         None
# 1       24947    0.001804         None
# 2       24947    0.001804         None
# 3       24947    0.001804         None
# 4       24947    0.001804         None
# 5       24947    0.001804         None
# 6       24947    0.001804         None
# 7       24947    0.001804         None
# 8       24947    0.001804         None
# 9       24947    0.001804         None
# 10      24947    0.001804         None
# 11      24947    0.001804         None
# 12      24947    0.001804         None
# 13      24947    0.001804         None
# 14      24947    0.001804         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.08,10))
# Out:
#       model        time       acc       pre      rec        f1       auc  \
# 0      ABOD    3.487653  0.998709  0.000000  0.00000  0.000000  0.500000
# 1     COPOD    0.013319  0.976083  0.026981  0.50000  0.051200  0.738349
# 2      ECOD    0.012617  0.963661  0.009040  0.25000  0.017448  0.607291
# 3       GMM    0.030768  0.981568  0.028825  0.40625  0.053830  0.694281
# 4      HBOS    0.004141  0.998387  0.000000  0.00000  0.000000  0.499838
# 5   IForest    1.363194  0.981649  0.028953  0.40625  0.054054  0.694321
# 6      INNE    2.173132  0.982536  0.028235  0.37500  0.052516  0.679161
# 7       KDE  100.878234  0.981124  0.028139  0.40625  0.052632  0.694059
# 8       KNN    0.097403  0.979632  0.026052  0.40625  0.048964  0.693312
# 9      LODA    0.137323  0.998387  0.000000  0.00000  0.000000  0.499838
# 10      LOF    0.158435  0.930104  0.000000  0.00000  0.000000  0.465653
# 11      MCD    0.013763  0.981568  0.028825  0.40625  0.053830  0.694281
# 12    OCSVM  224.847044  0.980721  0.027542  0.40625  0.051587  0.693857
# 13      PCA    0.005254  0.975720  0.013652  0.25000  0.025890  0.613329
# 14      ROD    4.514863  0.938009  0.000000  0.00000  0.000000  0.469611
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.056646       56306      [amt]     0.081022
# 1         False   pyod    0.056646       56306      [amt]     0.081022
# 2         False   pyod    0.056646       56306      [amt]     0.081022
# 3         False   pyod    0.056646       56306      [amt]     0.081022
# 4         False   pyod    0.056646       56306      [amt]     0.081022
# 5         False   pyod    0.056646       56306      [amt]     0.081022
# 6         False   pyod    0.056646       56306      [amt]     0.081022
# 7         False   pyod    0.056646       56306      [amt]     0.081022
# 8         False   pyod    0.056646       56306      [amt]     0.081022
# 9         False   pyod    0.056646       56306      [amt]     0.081022
# 10        False   pyod    0.056646       56306      [amt]     0.081022
# 11        False   pyod    0.056646       56306      [amt]     0.081022
# 12        False   pyod    0.056646       56306      [amt]     0.081022
# 13        False   pyod    0.056646       56306      [amt]     0.081022
# 14        False   pyod    0.056646       56306      [amt]     0.081022
#
#     test_size  test_frate hyper_params
# 0       24794    0.001291         None
# 1       24794    0.001291         None
# 2       24794    0.001291         None
# 3       24794    0.001291         None
# 4       24794    0.001291         None
# 5       24794    0.001291         None
# 6       24794    0.001291         None
# 7       24794    0.001291         None
# 8       24794    0.001291         None
# 9       24794    0.001291         None
# 10      24794    0.001291         None
# 11      24794    0.001291         None
# 12      24794    0.001291         None
# 13      24794    0.001291         None
# 14      24794    0.001291         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.07,10))
# Out:
#       model        time       acc       pre       rec        f1       auc  \
# 0      ABOD    2.962054  0.998456  0.000000  0.000000  0.000000  0.500000
# 1     COPOD    0.014464  0.977567  0.047535  0.710526  0.089109  0.844253
# 2      ECOD    0.013855  0.968911  0.023591  0.473684  0.044944  0.721681
# 3       GMM    0.070293  0.981916  0.052747  0.631579  0.097363  0.807018
# 4      HBOS    0.013217  0.996708  0.000000  0.000000  0.000000  0.499125
# 5   IForest    1.531945  0.981956  0.052863  0.631579  0.097561  0.807039
# 6      INNE    1.548968  0.979802  0.036364  0.473684  0.067542  0.727135
# 7       KDE  123.721325  0.981753  0.052288  0.631579  0.096579  0.806937
# 8       KNN    0.074193  0.980371  0.043121  0.552632  0.080000  0.766832
# 9      LODA    0.155255  0.996708  0.000000  0.000000  0.000000  0.499125
# 10      LOF    0.162841  0.944122  0.000000  0.000000  0.000000  0.472791
# 11      MCD    0.014444  0.981916  0.052747  0.631579  0.097363  0.807018
# 12    OCSVM  264.188841  0.981509  0.051613  0.631579  0.095427  0.806815
# 13      PCA    0.005749  0.980656  0.041841  0.526316  0.077519  0.753837
# 14      ROD    5.762914  0.944772  0.000000  0.000000  0.000000  0.473117
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.050879       64350      [amt]     0.069744
# 1         False   pyod    0.050879       64350      [amt]     0.069744
# 2         False   pyod    0.050879       64350      [amt]     0.069744
# 3         False   pyod    0.050879       64350      [amt]     0.069744
# 4         False   pyod    0.050879       64350      [amt]     0.069744
# 5         False   pyod    0.050879       64350      [amt]     0.069744
# 6         False   pyod    0.050879       64350      [amt]     0.069744
# 7         False   pyod    0.050879       64350      [amt]     0.069744
# 8         False   pyod    0.050879       64350      [amt]     0.069744
# 9         False   pyod    0.050879       64350      [amt]     0.069744
# 10        False   pyod    0.050879       64350      [amt]     0.069744
# 11        False   pyod    0.050879       64350      [amt]     0.069744
# 12        False   pyod    0.050879       64350      [amt]     0.069744
# 13        False   pyod    0.050879       64350      [amt]     0.069744
# 14        False   pyod    0.050879       64350      [amt]     0.069744
#
#     test_size  test_frate hyper_params
# 0       24607    0.001544         None
# 1       24607    0.001544         None
# 2       24607    0.001544         None
# 3       24607    0.001544         None
# 4       24607    0.001544         None
# 5       24607    0.001544         None
# 6       24607    0.001544         None
# 7       24607    0.001544         None
# 8       24607    0.001544         None
# 9       24607    0.001544         None
# 10      24607    0.001544         None
# 11      24607    0.001544         None
# 12      24607    0.001544         None
# 13      24607    0.001544         None
# 14      24607    0.001544         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.06,10))
# Out:
#       model        time       acc       pre    rec        f1       auc  \
# 0      ABOD    3.467247  0.998356  0.000000  0.000  0.000000  0.500000
# 1     COPOD    0.016381  0.979004  0.039139  0.500  0.072595  0.739896
# 2      ECOD    0.016149  0.971814  0.019345  0.325  0.036517  0.648939
# 3       GMM    0.063458  0.982702  0.045346  0.475  0.082789  0.729269
# 4      HBOS    0.004875  0.998110  0.000000  0.000  0.000000  0.499877
# 5   IForest    2.061922  0.982990  0.046117  0.475  0.084071  0.729413
# 6      INNE    2.461221  0.982702  0.045346  0.475  0.082789  0.729269
# 7       KDE  205.573256  0.982579  0.047170  0.500  0.086207  0.741687
# 8       KNN    0.091086  0.981510  0.042411  0.475  0.077869  0.728672
# 9      LODA    0.179124  0.998110  0.000000  0.000  0.000000  0.499877
# 10      LOF    0.191812  0.956159  0.000000  0.000  0.000000  0.478867
# 11      MCD    0.016367  0.982702  0.045346  0.475  0.082789  0.729269
# 12    OCSVM  400.278143  0.981962  0.045558  0.500  0.083507  0.741378
# 13      PCA    0.006584  0.980031  0.031513  0.375  0.058140  0.678014
# 14      ROD    5.229329  0.951064  0.000000  0.000  0.000000  0.476315
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.045346       75075      [amt]     0.059514
# 1         False   pyod    0.045346       75075      [amt]     0.059514
# 2         False   pyod    0.045346       75075      [amt]     0.059514
# 3         False   pyod    0.045346       75075      [amt]     0.059514
# 4         False   pyod    0.045346       75075      [amt]     0.059514
# 5         False   pyod    0.045346       75075      [amt]     0.059514
# 6         False   pyod    0.045346       75075      [amt]     0.059514
# 7         False   pyod    0.045346       75075      [amt]     0.059514
# 8         False   pyod    0.045346       75075      [amt]     0.059514
# 9         False   pyod    0.045346       75075      [amt]     0.059514
# 10        False   pyod    0.045346       75075      [amt]     0.059514
# 11        False   pyod    0.045346       75075      [amt]     0.059514
# 12        False   pyod    0.045346       75075      [amt]     0.059514
# 13        False   pyod    0.045346       75075      [amt]     0.059514
# 14        False   pyod    0.045346       75075      [amt]     0.059514
#
#     test_size  test_frate hyper_params
# 0       24338    0.001644         None
# 1       24338    0.001644         None
# 2       24338    0.001644         None
# 3       24338    0.001644         None
# 4       24338    0.001644         None
# 5       24338    0.001644         None
# 6       24338    0.001644         None
# 7       24338    0.001644         None
# 8       24338    0.001644         None
# 9       24338    0.001644         None
# 10      24338    0.001644         None
# 11      24338    0.001644         None
# 12      24338    0.001644         None
# 13      24338    0.001644         None
# 14      24338    0.001644         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.05,10))
# Out:
#       model        time       acc       pre       rec        f1       auc  \
# 0      ABOD    3.959457  0.998624  0.000000  0.000000  0.000000  0.500000
# 1     COPOD    0.019503  0.981313  0.033708  0.454545  0.062762  0.718292
# 2      ECOD    0.019603  0.976099  0.017857  0.303030  0.033727  0.640029
# 3       GMM    0.061655  0.983858  0.034211  0.393939  0.062954  0.689305
# 4      HBOS    0.015906  0.996496  0.000000  0.000000  0.000000  0.498935
# 5   IForest    2.054838  0.984108  0.034759  0.393939  0.063882  0.689430
# 6      INNE    2.139586  0.984275  0.035135  0.393939  0.064516  0.689514
# 7       KDE  244.665872  0.983524  0.033505  0.393939  0.061758  0.689138
# 8       KNN    0.111627  0.982606  0.029412  0.363636  0.054422  0.673548
# 9      LODA    0.211051  0.996496  0.000000  0.000000  0.000000  0.498935
# 10      LOF    0.225238  0.955535  0.000000  0.000000  0.000000  0.478426
# 11      MCD    0.019370  0.983858  0.034211  0.393939  0.062954  0.689305
# 12    OCSVM  662.775571  0.983399  0.030848  0.363636  0.056872  0.673945
# 13      PCA    0.007513  0.982898  0.029925  0.363636  0.055300  0.673694
# 14      ROD    5.626042  0.958872  0.000000  0.000000  0.000000  0.480097
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.039566       90090      [amt]     0.049728
# 1         False   pyod    0.039566       90090      [amt]     0.049728
# 2         False   pyod    0.039566       90090      [amt]     0.049728
# 3         False   pyod    0.039566       90090      [amt]     0.049728
# 4         False   pyod    0.039566       90090      [amt]     0.049728
# 5         False   pyod    0.039566       90090      [amt]     0.049728
# 6         False   pyod    0.039566       90090      [amt]     0.049728
# 7         False   pyod    0.039566       90090      [amt]     0.049728
# 8         False   pyod    0.039566       90090      [amt]     0.049728
# 9         False   pyod    0.039566       90090      [amt]     0.049728
# 10        False   pyod    0.039566       90090      [amt]     0.049728
# 11        False   pyod    0.039566       90090      [amt]     0.049728
# 12        False   pyod    0.039566       90090      [amt]     0.049728
# 13        False   pyod    0.039566       90090      [amt]     0.049728
# 14        False   pyod    0.039566       90090      [amt]     0.049728
#
#     test_size  test_frate hyper_params
# 0       23974    0.001376         None
# 1       23974    0.001376         None
# 2       23974    0.001376         None
# 3       23974    0.001376         None
# 4       23974    0.001376         None
# 5       23974    0.001376         None
# 6       23974    0.001376         None
# 7       23974    0.001376         None
# 8       23974    0.001376         None
# 9       23974    0.001376         None
# 10      23974    0.001376         None
# 11      23974    0.001376         None
# 12      23974    0.001376         None
# 13      23974    0.001376         None
# 14      23974    0.001376         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.04,10))
# Out:
#       model        time       acc       pre       rec        f1       auc  \
# 0      ABOD    4.956455  0.998332  0.000000  0.000000  0.000000  0.500000
# 1     COPOD    0.024607  0.981180  0.043280  0.487179  0.079498  0.734593
# 2      ECOD    0.024055  0.978315  0.026316  0.333333  0.048780  0.656363
# 3       GMM    0.039176  0.983533  0.047120  0.461538  0.085511  0.722972
# 4      HBOS    0.006186  0.997861  0.000000  0.000000  0.000000  0.499764
# 5   IForest    2.486076  0.983576  0.047244  0.461538  0.085714  0.722993
# 6      INNE    2.774405  0.984003  0.048518  0.461538  0.087805  0.723207
# 7       KDE  396.620954  0.983062  0.043478  0.435897  0.079070  0.709937
# 8       KNN    0.150895  0.982806  0.040506  0.410256  0.073733  0.697009
# 9      LODA    0.254971  0.997861  0.000000  0.000000  0.000000  0.499764
# 10      LOF    0.284254  0.960351  0.000000  0.000000  0.000000  0.480978
# 11      MCD    0.023309  0.983533  0.047120  0.461538  0.085511  0.722972
# 12    OCSVM  920.864878  0.982977  0.043257  0.435897  0.078704  0.709894
# 13      PCA    0.009444  0.983832  0.040650  0.384615  0.073529  0.684724
# 14      ROD    8.858874  0.964628  0.000000  0.000000  0.000000  0.483120
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.033678      112612      [amt]     0.040324
# 1         False   pyod    0.033678      112612      [amt]     0.040324
# 2         False   pyod    0.033678      112612      [amt]     0.040324
# 3         False   pyod    0.033678      112612      [amt]     0.040324
# 4         False   pyod    0.033678      112612      [amt]     0.040324
# 5         False   pyod    0.033678      112612      [amt]     0.040324
# 6         False   pyod    0.033678      112612      [amt]     0.040324
# 7         False   pyod    0.033678      112612      [amt]     0.040324
# 8         False   pyod    0.033678      112612      [amt]     0.040324
# 9         False   pyod    0.033678      112612      [amt]     0.040324
# 10        False   pyod    0.033678      112612      [amt]     0.040324
# 11        False   pyod    0.033678      112612      [amt]     0.040324
# 12        False   pyod    0.033678      112612      [amt]     0.040324
# 13        False   pyod    0.033678      112612      [amt]     0.040324
# 14        False   pyod    0.033678      112612      [amt]     0.040324
#
#     test_size  test_frate hyper_params
# 0       23380    0.001668         None
# 1       23380    0.001668         None
# 2       23380    0.001668         None
# 3       23380    0.001668         None
# 4       23380    0.001668         None
# 5       23380    0.001668         None
# 6       23380    0.001668         None
# 7       23380    0.001668         None
# 8       23380    0.001668         None
# 9       23380    0.001668         None
# 10      23380    0.001668         None
# 11      23380    0.001668         None
# 12      23380    0.001668         None
# 13      23380    0.001668         None
# 14      23380    0.001668         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.03,10))
# Out:
#       model         time       acc       pre       rec        f1       auc  \
# 0      ABOD     8.880860  0.998174  0.000000  0.000000  0.000000  0.500000
# 1     COPOD     0.039528  0.984550  0.050000  0.414634  0.089239  0.700113
# 2      ECOD     0.041628  0.982323  0.031579  0.292683  0.057007  0.638134
# 3       GMM     0.115207  0.986063  0.052632  0.390244  0.092754  0.688699
# 4      HBOS     0.022239  0.997863  0.000000  0.000000  0.000000  0.499844
# 5   IForest     4.673270  0.986108  0.052805  0.390244  0.093023  0.688721
# 6      INNE     6.086442  0.986820  0.055749  0.390244  0.097561  0.689078
# 7       KDE   796.511231  0.984372  0.041420  0.341463  0.073879  0.663505
# 8       KNN     0.173295  0.984461  0.044379  0.365854  0.079156  0.675723
# 9      LODA     0.264654  0.997863  0.000000  0.000000  0.000000  0.499844
# 10      LOF     0.299049  0.963489  0.002554  0.048780  0.004854  0.506971
# 11      MCD     0.028163  0.986063  0.052632  0.390244  0.092754  0.688699
# 12    OCSVM  1270.642886  0.983971  0.040346  0.341463  0.072165  0.663305
# 13      PCA     0.009664  0.986598  0.054795  0.390244  0.096096  0.688966
# 14      ROD     7.384326  0.964335  0.000000  0.000000  0.000000  0.483049
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod     0.02632      150150      [amt]     0.029983
# 1         False   pyod     0.02632      150150      [amt]     0.029983
# 2         False   pyod     0.02632      150150      [amt]     0.029983
# 3         False   pyod     0.02632      150150      [amt]     0.029983
# 4         False   pyod     0.02632      150150      [amt]     0.029983
# 5         False   pyod     0.02632      150150      [amt]     0.029983
# 6         False   pyod     0.02632      150150      [amt]     0.029983
# 7         False   pyod     0.02632      150150      [amt]     0.029983
# 8         False   pyod     0.02632      150150      [amt]     0.029983
# 9         False   pyod     0.02632      150150      [amt]     0.029983
# 10        False   pyod     0.02632      150150      [amt]     0.029983
# 11        False   pyod     0.02632      150150      [amt]     0.029983
# 12        False   pyod     0.02632      150150      [amt]     0.029983
# 13        False   pyod     0.02632      150150      [amt]     0.029983
# 14        False   pyod     0.02632      150150      [amt]     0.029983
#
#     test_size  test_frate hyper_params
# 0       22459    0.001826         None
# 1       22459    0.001826         None
# 2       22459    0.001826         None
# 3       22459    0.001826         None
# 4       22459    0.001826         None
# 5       22459    0.001826         None
# 6       22459    0.001826         None
# 7       22459    0.001826         None
# 8       22459    0.001826         None
# 9       22459    0.001826         None
# 10      22459    0.001826         None
# 11      22459    0.001826         None
# 12      22459    0.001826         None
# 13      22459    0.001826         None
# 14      22459    0.001826         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.02,10))
# Out:
#       model         time       acc       pre       rec        f1       auc  \
# 0      ABOD     8.893691  0.998205  0.000000  0.000000  0.000000  0.500000
# 1     COPOD     0.044242  0.989327  0.096916  0.594595  0.166667  0.792316
# 2      ECOD     0.044930  0.986853  0.063433  0.459459  0.111475  0.723630
# 3       GMM     0.040221  0.989715  0.100457  0.594595  0.171875  0.792510
# 4      HBOS     0.010299  0.997817  0.000000  0.000000  0.000000  0.499806
# 5   IForest     4.787790  0.989715  0.100457  0.594595  0.171875  0.792510
# 6      INNE     5.484649  0.990783  0.107692  0.567568  0.181034  0.779556
# 7       KDE  1390.294064  0.989230  0.096070  0.594595  0.165414  0.792267
# 8       KNN     0.300543  0.988696  0.070175  0.432432  0.120755  0.711065
# 9      LODA     0.367291  0.997817  0.000000  0.000000  0.000000  0.499806
# 10      LOF     0.496791  0.978509  0.000000  0.000000  0.000000  0.490134
# 11      MCD     0.038822  0.989715  0.100457  0.594595  0.171875  0.792510
# 12    OCSVM  3374.520427  0.988988  0.094017  0.594595  0.162362  0.792146
# 13      PCA     0.013737  0.989812  0.101382  0.594595  0.173228  0.792559
# 14      ROD     7.096717  0.970407  0.000000  0.000000  0.000000  0.486076
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.018366      225225      [amt]     0.019882
# 1         False   pyod    0.018366      225225      [amt]     0.019882
# 2         False   pyod    0.018366      225225      [amt]     0.019882
# 3         False   pyod    0.018366      225225      [amt]     0.019882
# 4         False   pyod    0.018366      225225      [amt]     0.019882
# 5         False   pyod    0.018366      225225      [amt]     0.019882
# 6         False   pyod    0.018366      225225      [amt]     0.019882
# 7         False   pyod    0.018366      225225      [amt]     0.019882
# 8         False   pyod    0.018366      225225      [amt]     0.019882
# 9         False   pyod    0.018366      225225      [amt]     0.019882
# 10        False   pyod    0.018366      225225      [amt]     0.019882
# 11        False   pyod    0.018366      225225      [amt]     0.019882
# 12        False   pyod    0.018366      225225      [amt]     0.019882
# 13        False   pyod    0.018366      225225      [amt]     0.019882
# 14        False   pyod    0.018366      225225      [amt]     0.019882
#
#     test_size  test_frate hyper_params
# 0       20613    0.001795         None
# 1       20613    0.001795         None
# 2       20613    0.001795         None
# 3       20613    0.001795         None
# 4       20613    0.001795         None
# 5       20613    0.001795         None
# 6       20613    0.001795         None
# 7       20613    0.001795         None
# 8       20613    0.001795         None
# 9       20613    0.001795         None
# 10      20613    0.001795         None
# 11      20613    0.001795         None
# 12      20613    0.001795         None
# 13      20613    0.001795         None
# 14      20613    0.001795         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.01,10))
# Out:
#       model          time       acc       pre       rec        f1       auc  \
# 0      ABOD     17.754313  0.997402  0.000000  0.000000  0.000000  0.500000
# 1     COPOD      0.088104  0.992738  0.181818  0.512821  0.268456  0.753404
# 2      ECOD      0.088064  0.989606  0.079137  0.282051  0.123596  0.636750
# 3       GMM      0.078605  0.992738  0.181818  0.512821  0.268456  0.753404
# 4      HBOS      0.019530  0.997002  0.000000  0.000000  0.000000  0.499800
# 5   IForest      9.426154  0.992804  0.183486  0.512821  0.270270  0.753438
# 6      INNE     11.323057  0.992338  0.141509  0.384615  0.206897  0.689268
# 7       KDE   6500.529283  0.992205  0.169492  0.512821  0.254777  0.753137
# 8       KNN      0.701913  0.992604  0.178571  0.512821  0.264901  0.753337
# 9      LODA      1.007189  0.997002  0.000000  0.000000  0.000000  0.499800
# 10      LOF      1.303235  0.986408  0.000000  0.000000  0.000000  0.494489
# 11      MCD      0.085595  0.992738  0.181818  0.512821  0.268456  0.753404
# 12    OCSVM  16973.566135  0.992138  0.168067  0.512821  0.253165  0.753104
# 13      PCA      0.026667  0.992738  0.181818  0.512821  0.268456  0.753404
# 14      ROD      9.401290  0.968419  0.000000  0.000000  0.000000  0.485471
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.009679      450450      [amt]     0.009915
# 1         False   pyod    0.009679      450450      [amt]     0.009915
# 2         False   pyod    0.009679      450450      [amt]     0.009915
# 3         False   pyod    0.009679      450450      [amt]     0.009915
# 4         False   pyod    0.009679      450450      [amt]     0.009915
# 5         False   pyod    0.009679      450450      [amt]     0.009915
# 6         False   pyod    0.009679      450450      [amt]     0.009915
# 7         False   pyod    0.009679      450450      [amt]     0.009915
# 8         False   pyod    0.009679      450450      [amt]     0.009915
# 9         False   pyod    0.009679      450450      [amt]     0.009915
# 10        False   pyod    0.009679      450450      [amt]     0.009915
# 11        False   pyod    0.009679      450450      [amt]     0.009915
# 12        False   pyod    0.009679      450450      [amt]     0.009915
# 13        False   pyod    0.009679      450450      [amt]     0.009915
# 14        False   pyod    0.009679      450450      [amt]     0.009915
#
#     test_size  test_frate hyper_params
# 0       15009    0.002598         None
# 1       15009    0.002598         None
# 2       15009    0.002598         None
# 3       15009    0.002598         None
# 4       15009    0.002598         None
# 5       15009    0.002598         None
# 6       15009    0.002598         None
# 7       15009    0.002598         None
# 8       15009    0.002598         None
# 9       15009    0.002598         None
# 10      15009    0.002598         None
# 11      15009    0.002598         None
# 12      15009    0.002598         None
# 13      15009    0.002598         None
# 14      15009    0.002598         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.009,10))
# Out:
#       model          time       acc       pre       rec        f1       auc  \
# 0      ABOD     19.123987  0.996802  0.000000  0.000000  0.000000  0.500000
# 1     COPOD      0.095501  0.993312  0.207317  0.386364  0.269841  0.690812
# 2      ECOD      0.094668  0.990841  0.090000  0.204545  0.125000  0.598955
# 3       GMM      0.082705  0.993385  0.209877  0.386364  0.272000  0.690848
# 4      HBOS      0.021790  0.996438  0.000000  0.000000  0.000000  0.499818
# 5   IForest     10.652711  0.993240  0.197531  0.363636  0.256000  0.679448
# 6      INNE     12.664726  0.990114  0.057692  0.136364  0.081081  0.564609
# 7       KDE   7850.544608  0.992731  0.174419  0.340909  0.230769  0.667866
# 8       KNN      0.720972  0.992513  0.175824  0.363636  0.237037  0.679084
# 9      LODA      0.847339  0.996438  0.000000  0.000000  0.000000  0.499818
# 10      LOF      1.163180  0.988370  0.000000  0.000000  0.000000  0.495770
# 11      MCD      0.085525  0.993385  0.209877  0.386364  0.272000  0.690848
# 12    OCSVM  16540.327188  0.992658  0.172414  0.340909  0.229008  0.667829
# 13      PCA      0.029995  0.993385  0.209877  0.386364  0.272000  0.690848
# 14      ROD      9.163085  0.971796  0.000000  0.000000  0.000000  0.487457
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod    0.008852      500499      [amt]     0.009007
# 1         False   pyod    0.008852      500499      [amt]     0.009007
# 2         False   pyod    0.008852      500499      [amt]     0.009007
# 3         False   pyod    0.008852      500499      [amt]     0.009007
# 4         False   pyod    0.008852      500499      [amt]     0.009007
# 5         False   pyod    0.008852      500499      [amt]     0.009007
# 6         False   pyod    0.008852      500499      [amt]     0.009007
# 7         False   pyod    0.008852      500499      [amt]     0.009007
# 8         False   pyod    0.008852      500499      [amt]     0.009007
# 9         False   pyod    0.008852      500499      [amt]     0.009007
# 10        False   pyod    0.008852      500499      [amt]     0.009007
# 11        False   pyod    0.008852      500499      [amt]     0.009007
# 12        False   pyod    0.008852      500499      [amt]     0.009007
# 13        False   pyod    0.008852      500499      [amt]     0.009007
# 14        False   pyod    0.008852      500499      [amt]     0.009007
#
#     test_size  test_frate hyper_params
# 0       13757    0.003198         None
# 1       13757    0.003198         None
# 2       13757    0.003198         None
# 3       13757    0.003198         None
# 4       13757    0.003198         None
# 5       13757    0.003198         None
# 6       13757    0.003198         None
# 7       13757    0.003198         None
# 8       13757    0.003198         None
# 9       13757    0.003198         None
# 10      13757    0.003198         None
# 11      13757    0.003198         None
# 12      13757    0.003198         None
# 13      13757    0.003198         None
# 14      13757    0.003198         None

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.008,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.007,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.006,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.15,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.25,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.35,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.45,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.55,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.015,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.025,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.035,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.045,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.055,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.065,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.075,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.085,10))

# %%
pyod(*pyod_preprocess7(fraudTrain, 0.095,10))

# %% [markdown]
# # pyod_preproecess10: 비율 다르게 test_size정할수 잇음

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.3, 0.05))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.3, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.05))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.0005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.1, 0.05))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.3, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.2, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.09, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.08, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.07, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.06, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.05, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.15, 0.005))

# %%
pyod(*pyod_preprocess10(fraudTrain, 0.25, 0.005))

# %% [markdown]
# # pyod_preprocess3: 비율 다 다르게 n

# %%
pyod(*pyod_preprocess3(fraudTrain, 10))

# %%
pyod(*pyod_preprocess3(fraudTrain, 9))

# %%
pyod(*pyod_preprocess3(fraudTrain, 5))

# %%
pyod(*pyod_preprocess3(fraudTrain, 4))

# %%
pyod(*pyod_preprocess3(fraudTrain, 2))

# %% [markdown]
# # 안됨(Replace has to be set to `True` when upsampling the population `frac` > 1.)

# %% [markdown]
# ```python
# pyod(*pyod_preprocess4(fraudTrain, 0.005))
#
# pyod(*pyod_preprocess7(fraudTrain, 0.005,10))
#
# pyod(*pyod_preprocess7(fraudTrain, 0.004,10))
#
# pyod(*pyod_preprocess7(fraudTrain, 0.003,10))
#
# pyod(*pyod_preprocess7(fraudTrain, 0.002,10))
#
# pyod(*pyod_preprocess7(fraudTrain, 0.001,10))
# ```

# %% [markdown]
# # contamination must be in (0, 0.5], got: 0.5~ 오류로 아래 것들 안 됨

# %% [markdown]
# ```python
# pyod(*pyod_preprocess3(fraudTrain, 8))
#
# pyod(*pyod_preprocess3(fraudTrain, 7))
#
# pyod(*pyod_preprocess3(fraudTrain, 6))
#
# pyod(*pyod_preprocess3(fraudTrain, 3))
#
# pyod(*pyod_preprocess3(fraudTrain, 1))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.5))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.05))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.5, 0.0005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.7, 0.005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.6, 0.005))
#
# pyod(*pyod_preprocess10(fraudTrain, 0.4, 0.005))
# ```
