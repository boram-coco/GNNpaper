# %% [raw]
# ---
# title: "[Pyod] df0.03~0.01"
# author: "김보람 "
# date: "02/22/2024"
# ---

# %% [markdown]
# ref: <https://pyod.readthedocs.io/en/latest/pyod.models.html#all-models>
#
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions_pyod2.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %% [markdown]
# # 2.

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.03))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7ff643500d30>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model         time       acc       pre       rec        f1       auc  \
# 0      ECOD     0.330842  0.964256  0.408638  0.406209  0.407420  0.693936
# 1       GMM     0.171471  0.971329  0.525500  0.537649  0.531505  0.761253
# 2      HBOS     0.913240  0.969311  0.000000  0.000000  0.000000  0.499773
# 3   IForest     3.476480  0.971389  0.526554  0.536988  0.531720  0.760964
# 4      INNE     5.219564  0.971568  0.529836  0.533686  0.531754  0.759457
# 5       KDE   674.120848  0.971469  0.527599  0.542933  0.535156  0.763884
# 6       KNN     0.254292  0.971568  0.529111  0.546235  0.537537  0.765536
# 7      LODA     2.639494  0.969311  0.000000  0.000000  0.000000  0.499773
# 8       LOF     0.482762  0.934266  0.032632  0.040951  0.036321  0.501541
# 9       MCD     0.280915  0.971329  0.525500  0.537649  0.531505  0.761253
# 10    OCSVM  1591.306485  0.971389  0.526215  0.543593  0.534763  0.764163
# 11      PCA     0.028368  0.970270  0.508508  0.513210  0.510848  0.748868
# 12      ROD     8.423047  0.939041  0.000650  0.000661  0.000655  0.484486
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.03      150150      [amt]     0.029917
# 1         False   pyod        0.03      150150      [amt]     0.029917
# 2         False   pyod        0.03      150150      [amt]     0.029917
# 3         False   pyod        0.03      150150      [amt]     0.029917
# 4         False   pyod        0.03      150150      [amt]     0.029917
# 5         False   pyod        0.03      150150      [amt]     0.029917
# 6         False   pyod        0.03      150150      [amt]     0.029917
# 7         False   pyod        0.03      150150      [amt]     0.029917
# 8         False   pyod        0.03      150150      [amt]     0.029917
# 9         False   pyod        0.03      150150      [amt]     0.029917
# 10        False   pyod        0.03      150150      [amt]     0.029917
# 11        False   pyod        0.03      150150      [amt]     0.029917
# 12        False   pyod        0.03      150150      [amt]     0.029917
#
#     test_size  test_frate hyper_params
# 0       50050     0.03025         None
# 1       50050     0.03025         None
# 2       50050     0.03025         None
# 3       50050     0.03025         None
# 4       50050     0.03025         None
# 5       50050     0.03025         None
# 6       50050     0.03025         None
# 7       50050     0.03025         None
# 8       50050     0.03025         None
# 9       50050     0.03025         None
# 10      50050     0.03025         None
# 11      50050     0.03025         None
# 12      50050     0.03025         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.02))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7ff652a0ee50>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model         time       acc       pre       rec        f1       auc  \
# 0      ECOD     0.048353  0.973413  0.342277  0.345443  0.343853  0.665890
# 1       GMM     0.122125  0.980140  0.507703  0.500661  0.504157  0.745334
# 2      HBOS     0.008320  0.979527  0.000000  0.000000  0.000000  0.499844
# 3   IForest     5.214050  0.980140  0.507703  0.500661  0.504157  0.745334
# 4      INNE     7.442253  0.978235  0.458848  0.441876  0.450202  0.715575
# 5       KDE  1384.255661  0.978741  0.474439  0.502642  0.488133  0.745591
# 6       KNN     0.309763  0.978222  0.460689  0.468296  0.464461  0.728506
# 7      LODA     0.619595  0.979527  0.000000  0.000000  0.000000  0.499844
# 8       LOF     0.494502  0.961292  0.004979  0.004624  0.004795  0.492803
# 9       MCD     0.055974  0.980140  0.507703  0.500661  0.504157  0.745334
# 10    OCSVM  2769.511098  0.978701  0.473586  0.503303  0.487992  0.745894
# 11      PCA     0.015658  0.979953  0.503026  0.494055  0.498500  0.742005
# 12      ROD    10.915194  0.959614  0.000000  0.000000  0.000000  0.489682
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.02      225225      [amt]     0.019944
# 1         False   pyod        0.02      225225      [amt]     0.019944
# 2         False   pyod        0.02      225225      [amt]     0.019944
# 3         False   pyod        0.02      225225      [amt]     0.019944
# 4         False   pyod        0.02      225225      [amt]     0.019944
# 5         False   pyod        0.02      225225      [amt]     0.019944
# 6         False   pyod        0.02      225225      [amt]     0.019944
# 7         False   pyod        0.02      225225      [amt]     0.019944
# 8         False   pyod        0.02      225225      [amt]     0.019944
# 9         False   pyod        0.02      225225      [amt]     0.019944
# 10        False   pyod        0.02      225225      [amt]     0.019944
# 11        False   pyod        0.02      225225      [amt]     0.019944
# 12        False   pyod        0.02      225225      [amt]     0.019944
#
#     test_size  test_frate hyper_params
# 0       75075    0.020167         None
# 1       75075    0.020167         None
# 2       75075    0.020167         None
# 3       75075    0.020167         None
# 4       75075    0.020167         None
# 5       75075    0.020167         None
# 6       75075    0.020167         None
# 7       75075    0.020167         None
# 8       75075    0.020167         None
# 9       75075    0.020167         None
# 10      75075    0.020167         None
# 11      75075    0.020167         None
# 12      75075    0.020167         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.01))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7ff689e4b8b0>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model          time       acc       pre       rec        f1       auc  \
# 0      ECOD      0.093907  0.984555  0.251647  0.244089  0.247811  0.618222
# 1       GMM      0.128739  0.989491  0.495641  0.472204  0.483639  0.733572
# 2      HBOS      0.013668  0.989284  0.000000  0.000000  0.000000  0.499852
# 3   IForest     10.198188  0.989624  0.502383  0.471565  0.486486  0.733323
# 4      INNE     16.469790  0.988372  0.437886  0.407668  0.422237  0.701078
# 5       KDE   5853.300178  0.988745  0.459016  0.447284  0.453074  0.720866
# 6       KNN      0.666940  0.987719  0.406938  0.389776  0.398172  0.691897
# 7      LODA      1.198275  0.989284  0.000000  0.000000  0.000000  0.499852
# 8       LOF      1.107466  0.979980  0.004811  0.004473  0.004636  0.497364
# 9       MCD      0.092024  0.989491  0.495641  0.472204  0.483639  0.733572
# 10    OCSVM  13195.876470  0.988758  0.459778  0.449201  0.454428  0.721821
# 11      PCA      0.026801  0.989491  0.495641  0.472204  0.483639  0.733572
# 12      ROD     14.318378  0.980693  0.001495  0.001278  0.001378  0.496143
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.01      450450      [amt]     0.009859
# 1         False   pyod        0.01      450450      [amt]     0.009859
# 2         False   pyod        0.01      450450      [amt]     0.009859
# 3         False   pyod        0.01      450450      [amt]     0.009859
# 4         False   pyod        0.01      450450      [amt]     0.009859
# 5         False   pyod        0.01      450450      [amt]     0.009859
# 6         False   pyod        0.01      450450      [amt]     0.009859
# 7         False   pyod        0.01      450450      [amt]     0.009859
# 8         False   pyod        0.01      450450      [amt]     0.009859
# 9         False   pyod        0.01      450450      [amt]     0.009859
# 10        False   pyod        0.01      450450      [amt]     0.009859
# 11        False   pyod        0.01      450450      [amt]     0.009859
# 12        False   pyod        0.01      450450      [amt]     0.009859
#
#     test_size  test_frate hyper_params
# 0      150150    0.010423         None
# 1      150150    0.010423         None
# 2      150150    0.010423         None
# 3      150150    0.010423         None
# 4      150150    0.010423         None
# 5      150150    0.010423         None
# 6      150150    0.010423         None
# 7      150150    0.010423         None
# 8      150150    0.010423         None
# 9      150150    0.010423         None
# 10     150150    0.010423         None
# 11     150150    0.010423         None
# 12     150150    0.010423         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.00573))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fb788701670>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.350781  0.989826  0.120474  0.120952  0.120712  0.557912
# 1       GMM   0.236045  0.992898  0.382114  0.372769  0.377384  0.684634
# 2      HBOS   0.902830  0.993978  0.000000  0.000000  0.000000  0.499875
# 3   IForest  18.316931  0.992913  0.381706  0.366821  0.374115  0.681685
# 4      INNE  25.323826  0.992921  0.375727  0.341705  0.357909  0.669204
# 5       KNN   1.392572  0.992047  0.299085  0.280899  0.289707  0.638538
# 6      LODA   2.211522  0.993978  0.000000  0.000000  0.000000  0.499875
# 7       LOF   2.140320  0.988784  0.000700  0.000661  0.000680  0.497592
# 8       MCD   0.158081  0.992898  0.382114  0.372769  0.377384  0.684634
# 9       PCA   0.048425  0.992898  0.382114  0.372769  0.377384  0.684634
# 10      ROD  15.528072  0.989330  0.000000  0.000000  0.000000  0.497538
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod     0.00573      786126      [amt]     0.005715
# 1         False   pyod     0.00573      786126      [amt]     0.005715
# 2         False   pyod     0.00573      786126      [amt]     0.005715
# 3         False   pyod     0.00573      786126      [amt]     0.005715
# 4         False   pyod     0.00573      786126      [amt]     0.005715
# 5         False   pyod     0.00573      786126      [amt]     0.005715
# 6         False   pyod     0.00573      786126      [amt]     0.005715
# 7         False   pyod     0.00573      786126      [amt]     0.005715
# 8         False   pyod     0.00573      786126      [amt]     0.005715
# 9         False   pyod     0.00573      786126      [amt]     0.005715
# 10        False   pyod     0.00573      786126      [amt]     0.005715
#
#     test_size  test_frate hyper_params
# 0      262042    0.005774         None
# 1      262042    0.005774         None
# 2      262042    0.005774         None
# 3      262042    0.005774         None
# 4      262042    0.005774         None
# 5      262042    0.005774         None
# 6      262042    0.005774         None
# 7      262042    0.005774         None
# 8      262042    0.005774         None
# 9      262042    0.005774         None
# 10     262042    0.005774         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.006))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fb797b45430>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.162771  0.989463  0.124495  0.121631  0.123046  0.558200
# 1       GMM   0.169849  0.992663  0.397926  0.403682  0.400783  0.699973
# 2      HBOS   0.021995  0.993634  0.000000  0.000000  0.000000  0.499855
# 3   IForest  17.540598  0.992675  0.396962  0.395135  0.396046  0.695732
# 4      INNE  26.054414  0.989822  0.168605  0.171598  0.170088  0.583212
# 5       KNN   1.361148  0.991524  0.304688  0.307692  0.306183  0.651699
# 6      LODA   2.033969  0.993634  0.000000  0.000000  0.000000  0.499855
# 7       LOF   2.033125  0.987644  0.001902  0.001972  0.001937  0.497822
# 8       MCD   0.153317  0.992663  0.397926  0.403682  0.400783  0.699973
# 9       PCA   0.044844  0.992663  0.397926  0.403682  0.400783  0.699973
# 10      ROD  14.036913  0.984663  0.000000  0.000000  0.000000  0.495342
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.006      750750      [amt]     0.005974
# 1         False   pyod       0.006      750750      [amt]     0.005974
# 2         False   pyod       0.006      750750      [amt]     0.005974
# 3         False   pyod       0.006      750750      [amt]     0.005974
# 4         False   pyod       0.006      750750      [amt]     0.005974
# 5         False   pyod       0.006      750750      [amt]     0.005974
# 6         False   pyod       0.006      750750      [amt]     0.005974
# 7         False   pyod       0.006      750750      [amt]     0.005974
# 8         False   pyod       0.006      750750      [amt]     0.005974
# 9         False   pyod       0.006      750750      [amt]     0.005974
# 10        False   pyod       0.006      750750      [amt]     0.005974
#
#     test_size  test_frate hyper_params
# 0      250250    0.006078         None
# 1      250250    0.006078         None
# 2      250250    0.006078         None
# 3      250250    0.006078         None
# 4      250250    0.006078         None
# 5      250250    0.006078         None
# 6      250250    0.006078         None
# 7      250250    0.006078         None
# 8      250250    0.006078         None
# 9      250250    0.006078         None
# 10     250250    0.006078         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.007))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fb7833da940>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.137144  0.988294  0.157548  0.162364  0.159920  0.578182
# 1       GMM   0.156920  0.991977  0.417055  0.425272  0.421123  0.710582
# 2      HBOS   0.019263  0.992429  0.000000  0.000000  0.000000  0.499643
# 3   IForest  15.022478  0.992005  0.418071  0.421196  0.419628  0.708572
# 4      INNE  22.330099  0.992051  0.416368  0.394022  0.404887  0.695103
# 5       KNN   1.042205  0.990620  0.318059  0.320652  0.319350  0.657951
# 6      LODA   1.774493  0.992429  0.000000  0.000000  0.000000  0.499643
# 7       LOF   1.573942  0.986527  0.002107  0.002038  0.002072  0.497684
# 8       MCD   0.127130  0.991977  0.417055  0.425272  0.421123  0.710582
# 9       PCA   0.037109  0.991977  0.417055  0.425272  0.421123  0.710582
# 10      ROD  15.755857  0.982065  0.000000  0.000000  0.000000  0.494426
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.007      643500      [amt]     0.007046
# 1         False   pyod       0.007      643500      [amt]     0.007046
# 2         False   pyod       0.007      643500      [amt]     0.007046
# 3         False   pyod       0.007      643500      [amt]     0.007046
# 4         False   pyod       0.007      643500      [amt]     0.007046
# 5         False   pyod       0.007      643500      [amt]     0.007046
# 6         False   pyod       0.007      643500      [amt]     0.007046
# 7         False   pyod       0.007      643500      [amt]     0.007046
# 8         False   pyod       0.007      643500      [amt]     0.007046
# 9         False   pyod       0.007      643500      [amt]     0.007046
# 10        False   pyod       0.007      643500      [amt]     0.007046
#
#     test_size  test_frate hyper_params
# 0      214500    0.006862         None
# 1      214500    0.006862         None
# 2      214500    0.006862         None
# 3      214500    0.006862         None
# 4      214500    0.006862         None
# 5      214500    0.006862         None
# 6      214500    0.006862         None
# 7      214500    0.006862         None
# 8      214500    0.006862         None
# 9      214500    0.006862         None
# 10     214500    0.006862         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.008))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fb797b45430>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.119038  0.987053  0.194964  0.203367  0.199077  0.598335
# 1       GMM   0.144922  0.991166  0.442448  0.447811  0.445114  0.721655
# 2      HBOS   0.016834  0.991758  0.000000  0.000000  0.000000  0.499834
# 3   IForest  13.051786  0.991182  0.443106  0.445791  0.444444  0.720662
# 4      INNE  19.702755  0.991315  0.449265  0.432323  0.440631  0.714048
# 5       KNN   0.860021  0.989717  0.352747  0.358923  0.355808  0.676835
# 6      LODA   1.489719  0.991758  0.000000  0.000000  0.000000  0.499834
# 7       LOF   1.370956  0.984426  0.000694  0.000673  0.000684  0.496473
# 8       MCD   0.113501  0.991166  0.442448  0.447811  0.445114  0.721655
# 9       PCA   0.032855  0.991166  0.442448  0.447811  0.445114  0.721655
# 10      ROD  14.830936  0.981533  0.000504  0.000673  0.000577  0.495015
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.008      563062      [amt]     0.008029
# 1         False   pyod       0.008      563062      [amt]     0.008029
# 2         False   pyod       0.008      563062      [amt]     0.008029
# 3         False   pyod       0.008      563062      [amt]     0.008029
# 4         False   pyod       0.008      563062      [amt]     0.008029
# 5         False   pyod       0.008      563062      [amt]     0.008029
# 6         False   pyod       0.008      563062      [amt]     0.008029
# 7         False   pyod       0.008      563062      [amt]     0.008029
# 8         False   pyod       0.008      563062      [amt]     0.008029
# 9         False   pyod       0.008      563062      [amt]     0.008029
# 10        False   pyod       0.008      563062      [amt]     0.008029
#
#     test_size  test_frate hyper_params
# 0      187688    0.007912         None
# 1      187688    0.007912         None
# 2      187688    0.007912         None
# 3      187688    0.007912         None
# 4      187688    0.007912         None
# 5      187688    0.007912         None
# 6      187688    0.007912         None
# 7      187688    0.007912         None
# 8      187688    0.007912         None
# 9      187688    0.007912         None
# 10     187688    0.007912         None

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.009))
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fb7833daee0>
# Traceback (most recent call last):
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/coco/anaconda3/envs/py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.102734  0.985980  0.213324  0.213181  0.213253  0.603055
# 1       GMM   0.139226  0.990787  0.482782  0.471419  0.477033  0.733439
# 2      HBOS   0.014991  0.990775  0.000000  0.000000  0.000000  0.499843
# 3   IForest  11.497505  0.990757  0.480916  0.466039  0.473361  0.730758
# 4      INNE  16.159571  0.989606  0.413937  0.399462  0.406571  0.697188
# 5       KNN   0.733732  0.989187  0.392250  0.388030  0.390128  0.691311
# 6      LODA   1.380267  0.990775  0.000000  0.000000  0.000000  0.499843
# 7       LOF   1.171791  0.982414  0.001378  0.001345  0.001361  0.496291
# 8       MCD   0.101797  0.990787  0.482782  0.471419  0.477033  0.733439
# 9       PCA   0.029553  0.990787  0.482782  0.471419  0.477033  0.733439
# 10      ROD  15.238129  0.978524  0.000477  0.000672  0.000558  0.493995
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod       0.009      500499      [amt]     0.009029
# 1         False   pyod       0.009      500499      [amt]     0.009029
# 2         False   pyod       0.009      500499      [amt]     0.009029
# 3         False   pyod       0.009      500499      [amt]     0.009029
# 4         False   pyod       0.009      500499      [amt]     0.009029
# 5         False   pyod       0.009      500499      [amt]     0.009029
# 6         False   pyod       0.009      500499      [amt]     0.009029
# 7         False   pyod       0.009      500499      [amt]     0.009029
# 8         False   pyod       0.009      500499      [amt]     0.009029
# 9         False   pyod       0.009      500499      [amt]     0.009029
# 10        False   pyod       0.009      500499      [amt]     0.009029
#
#     test_size  test_frate hyper_params
# 0      166834    0.008913         None
# 1      166834    0.008913         None
# 2      166834    0.008913         None
# 3      166834    0.008913         None
# 4      166834    0.008913         None
# 5      166834    0.008913         None
# 6      166834    0.008913         None
# 7      166834    0.008913         None
# 8      166834    0.008913         None
# 9      166834    0.008913         None
# 10     166834    0.008913         None
