# %% [raw]
# ---
# title: "[Pyod] df0.04_tr,df0.04_tst def"
# author: "김보람 "
# date: "02/20/2024"
# ---

# %% [markdown]
# 1. 2/20
#
# 2. 4/5

# %% [markdown]
# ref: <https://pyod.readthedocs.io/en/latest/pyod.models.html#all-models>
#
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ../functions_pyod2.py

# %%
with open('../fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %% [markdown]
# # 2.

# %%
pyod(*pyod_preprocess4(fraudTrain, 0.04))
# Out:
#       model       time       acc       pre       rec        f1       auc  \
# 0      ECOD   0.294062  0.952608  0.399732  0.402703  0.401212  0.688941
# 1       GMM   0.194865  0.967233  0.582891  0.593919  0.588353  0.788237
# 2      HBOS   1.260800  0.960200  0.000000  0.000000  0.000000  0.499806
# 3   IForest   2.935398  0.967180  0.582667  0.590541  0.586577  0.786590
# 4      INNE   3.616225  0.967526  0.588957  0.583784  0.586359  0.783530
# 5       KNN   0.199255  0.964436  0.548560  0.553378  0.550959  0.767343
# 6      LODA   0.895082  0.960200  0.000000  0.000000  0.000000  0.499806
# 7       LOF   0.382876  0.915579  0.026360  0.031757  0.028808  0.491806
# 8       MCD   0.084047  0.967233  0.582891  0.593919  0.588353  0.788237
# 9       PCA   0.031701  0.957989  0.467602  0.472973  0.470272  0.725435
# 10      ROD  13.019157  0.920134  0.000658  0.000676  0.000667  0.479275
#
#     graph_based method  throw_rate  train_size train_cols  train_frate  \
# 0         False   pyod        0.04      112612      [amt]     0.040191
# 1         False   pyod        0.04      112612      [amt]     0.040191
# 2         False   pyod        0.04      112612      [amt]     0.040191
# 3         False   pyod        0.04      112612      [amt]     0.040191
# 4         False   pyod        0.04      112612      [amt]     0.040191
# 5         False   pyod        0.04      112612      [amt]     0.040191
# 6         False   pyod        0.04      112612      [amt]     0.040191
# 7         False   pyod        0.04      112612      [amt]     0.040191
# 8         False   pyod        0.04      112612      [amt]     0.040191
# 9         False   pyod        0.04      112612      [amt]     0.040191
# 10        False   pyod        0.04      112612      [amt]     0.040191
#
#     test_size  test_frate hyper_params
# 0       37538    0.039427         None
# 1       37538    0.039427         None
# 2       37538    0.039427         None
# 3       37538    0.039427         None
# 4       37538    0.039427         None
# 5       37538    0.039427         None
# 6       37538    0.039427         None
# 7       37538    0.039427         None
# 8       37538    0.039427         None
# 9       37538    0.039427         None
# 10      37538    0.039427         None
